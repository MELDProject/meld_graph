# %%
import meld_graph
import meld_graph.models
import meld_graph.experiment
import meld_graph.dataset
import meld_graph.data_preprocessing
import meld_graph.icospheres

import importlib
importlib.reload(meld_graph)
importlib.reload(meld_graph.models)
importlib.reload(meld_graph.dataset)
importlib.reload(meld_graph.experiment)
importlib.reload(meld_graph.data_preprocessing)

from meld_graph.paths import EXPERIMENT_PATH
import numpy as np

import logging
import argparse
from copy import deepcopy
import os
from functools import reduce
import operator
# Out:
# Setting MELD_DATA_PATH to /home/co-spit1/meld_data
# Setting BASE_PATH to /home/co-spit1/meld_data
# Setting EXPERIMENT_PATH to /home/co-spit1/meld_experiments/co-spit1
# Setting FS_SUBJECTS_PATH to /home/co-spit1/meld_data/output/fs_outputs
# Setting EXPERIMENT_PATH to /rds/project/kw350/rds-kw350-meld/experiments_graph/co-spit1

# %%
def load_config(config_file):
    """load config.py file and return config object"""
    import importlib.machinery, importlib.util

    loader = importlib.machinery.SourceFileLoader("config", config_file)
    spec = importlib.util.spec_from_loader(loader.name, loader)
    config = importlib.util.module_from_spec(spec)
    loader.exec_module(config)
    return config

# %%
config = load_config("../scripts/config_files/experiment_config_hannah.py")

# %%
exp = meld_graph.experiment.Experiment(config.network_parameters, config.data_parameters, verbose=logging.INFO)
# Out:
# saving parameter files to /rds/project/kw350/rds-kw350-meld/experiments_graph/co-spit1/22-06-24_lr_decay/fold_00

# %%
config.data_parameters
# Out:
# {'hdf5_file_root': '{site_code}_{group}_featurematrix_combat_6.hdf5',
#  'site_codes': ['H4'],
#  'scanners': ['15T', '3T'],
#  'dataset': 'MELD_dataset_V6.csv',
#  'group': 'both',
#  'features_to_exclude': [],
#  'subject_features_to_exclude': [],
#  'features': ['.on_lh.lesion.mgh', '.combat.on_lh.pial.K_filtered.sm20.mgh'],
#  'features_to_replace_with_0': [],
#  'number_of_folds': 10,
#  'fold_n': 0,
#  'preprocessing_parameters': {'scaling': None, 'zscore': True},
#  'icosphere_parameters': {'distance_type': 'exact'},
#  'augment_data': {},
#  'combine_hemis': None,
#  'lobes': False,
#  'lesion_bias': 0}

# %%
trainer = meld_graph.training.Trainer(exp)

# %%
trainer.train()
# Out:
# Using coord type exact
# getting train val test split
# total number of subjects: 86
# total number of subjects after restricting to subjects from MELD_dataset_V6.csv: 86
# total number of subjects: 950
# total number of subjects after restricting to subjects from MELD_dataset_V6.csv: 942
# total number after filtering by scanner ['3T', '15T'], features, lesional_only True: 911
# full_feature_list: ['.combat.on_lh.curv.sm5.mgh', '.combat.on_lh.gm_FLAIR_0.25.sm10.mgh', '.combat.on_lh.gm_FLAIR_0.5.sm10.mgh', '.combat.on_lh.gm_FLAIR_0.75.sm10.mgh', '.combat.on_lh.gm_FLAIR_0.sm10.mgh', '.combat.on_lh.pial.K_filtered.sm20.mgh', '.combat.on_lh.sulc.sm5.mgh', '.combat.on_lh.thickness.sm10.mgh', '.combat.on_lh.w-g.pct.sm10.mgh', '.combat.on_lh.wm_FLAIR_0.5.sm10.mgh', '.combat.on_lh.wm_FLAIR_1.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.curv.sm5.mgh', '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.25.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.5.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.pial.K_filtered.sm20.mgh', '.inter_z.asym.intra_z.combat.on_lh.sulc.sm5.mgh', '.inter_z.asym.intra_z.combat.on_lh.thickness.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.w-g.pct.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.wm_FLAIR_0.5.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.wm_FLAIR_1.sm10.mgh', '.inter_z.intra_z.combat.on_lh.curv.sm5.mgh', '.inter_z.intra_z.combat.on_lh.gm_FLAIR_0.25.sm10.mgh', '.inter_z.intra_z.combat.on_lh.gm_FLAIR_0.5.sm10.mgh', '.inter_z.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh', '.inter_z.intra_z.combat.on_lh.gm_FLAIR_0.sm10.mgh', '.inter_z.intra_z.combat.on_lh.pial.K_filtered.sm20.mgh', '.inter_z.intra_z.combat.on_lh.sulc.sm5.mgh', '.inter_z.intra_z.combat.on_lh.thickness.sm10.mgh', '.inter_z.intra_z.combat.on_lh.w-g.pct.sm10.mgh', '.inter_z.intra_z.combat.on_lh.wm_FLAIR_0.5.sm10.mgh', '.inter_z.intra_z.combat.on_lh.wm_FLAIR_1.sm10.mgh']
# total number after filtering by scanner ['15T', '3T'], features, lesional_only True: 86
# /home/co-spit1/.conda/envs/meld_test/lib/python3.9/site-packages/numpy/core/numeric.py:1211: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   a = asanyarray(a)
# saving parameter files to /rds/project/kw350/rds-kw350-meld/experiments_graph/co-spit1/22-06-24_lr_decay/fold_00
# Loading and preprocessing data
# Combine hemis None
# Loading and preprocessing data
# Combine hemis None
# Epoch 0 :: learning rate 0.0001
# Epoch 0 :: Train loss 0.105, dice_lesion 0.031, dice_nonlesion 0.557, precision 0.016, recall 0.998, tp 91913.000, fp 5679045.000, fn 176.000, tn 176.000
# Epoch 0 :: Val   loss 0.108, dice_lesion 0.002, dice_nonlesion 0.555, precision 0.001, recall 1.000, tp 697.000, fp 807191.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 1 :: learning rate 0.0001
# Epoch 1 :: Train loss 0.105, dice_lesion 0.040, dice_nonlesion 0.558, precision 0.021, recall 0.997, tp 123311.000, fp 5643584.000, fn 325.000, tn 325.000
# Epoch 1 :: Val   loss 0.105, dice_lesion 0.002, dice_nonlesion 0.557, precision 0.001, recall 1.000, tp 697.000, fp 803847.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 2 :: learning rate 0.0001
# Epoch 2 :: Train loss 0.100, dice_lesion 0.038, dice_nonlesion 0.561, precision 0.020, recall 0.998, tp 117668.000, fp 5627674.000, fn 178.000, tn 178.000
# Epoch 2 :: Val   loss 0.101, dice_lesion 0.002, dice_nonlesion 0.561, precision 0.001, recall 1.000, tp 697.000, fp 798736.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 3 :: learning rate 0.0001
# Epoch 3 :: Train loss 0.096, dice_lesion 0.038, dice_nonlesion 0.567, precision 0.019, recall 0.999, tp 110549.000, fp 5570795.000, fn 165.000, tn 165.000
# Epoch 3 :: Val   loss 0.096, dice_lesion 0.002, dice_nonlesion 0.566, precision 0.001, recall 1.000, tp 697.000, fp 792652.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 4 :: learning rate 0.0001
# Epoch 4 :: Train loss 0.091, dice_lesion 0.037, dice_nonlesion 0.570, precision 0.019, recall 0.999, tp 107432.000, fp 5553231.000, fn 155.000, tn 155.000
# Epoch 4 :: Val   loss 0.091, dice_lesion 0.002, dice_nonlesion 0.572, precision 0.001, recall 1.000, tp 697.000, fp 785605.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 5 :: learning rate 0.0001
# Epoch 5 :: Train loss 0.086, dice_lesion 0.035, dice_nonlesion 0.577, precision 0.018, recall 0.999, tp 101608.000, fp 5489486.000, fn 147.000, tn 147.000
# Epoch 5 :: Val   loss 0.086, dice_lesion 0.002, dice_nonlesion 0.578, precision 0.001, recall 1.000, tp 697.000, fp 777801.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 6 :: learning rate 0.0001
# Epoch 6 :: Train loss 0.081, dice_lesion 0.037, dice_nonlesion 0.589, precision 0.020, recall 0.999, tp 109250.000, fp 5392229.000, fn 148.000, tn 148.000
# Epoch 6 :: Val   loss 0.081, dice_lesion 0.002, dice_nonlesion 0.584, precision 0.001, recall 1.000, tp 697.000, fp 769265.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 7 :: learning rate 0.0001
# Epoch 7 :: Train loss 0.076, dice_lesion 0.038, dice_nonlesion 0.593, precision 0.021, recall 0.998, tp 112645.000, fp 5332434.000, fn 261.000, tn 261.000
# Epoch 7 :: Val   loss 0.076, dice_lesion 0.002, dice_nonlesion 0.591, precision 0.001, recall 1.000, tp 697.000, fp 760059.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 8 :: learning rate 0.0001
# Epoch 8 :: Train loss 0.072, dice_lesion 0.038, dice_nonlesion 0.598, precision 0.021, recall 0.999, tp 110956.000, fp 5280054.000, fn 121.000, tn 121.000
# Epoch 8 :: Val   loss 0.071, dice_lesion 0.002, dice_nonlesion 0.598, precision 0.001, recall 1.000, tp 697.000, fp 750364.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 9 :: learning rate 0.0001
# Epoch 9 :: Train loss 0.066, dice_lesion 0.044, dice_nonlesion 0.613, precision 0.022, recall 0.999, tp 115753.000, fp 5144789.000, fn 120.000, tn 120.000
# Epoch 9 :: Val   loss 0.066, dice_lesion 0.002, dice_nonlesion 0.606, precision 0.001, recall 1.000, tp 697.000, fp 740467.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 10 :: learning rate 0.0001
# Epoch 10 :: Train loss 0.063, dice_lesion 0.036, dice_nonlesion 0.614, precision 0.019, recall 0.999, tp 98115.000, fp 5154395.000, fn 96.000, tn 96.000
# Epoch 10 :: Val   loss 0.062, dice_lesion 0.002, dice_nonlesion 0.614, precision 0.001, recall 1.000, tp 697.000, fp 729909.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 11 :: learning rate 0.0001
# Epoch 11 :: Train loss 0.058, dice_lesion 0.037, dice_nonlesion 0.623, precision 0.019, recall 0.998, tp 99395.000, fp 5050084.000, fn 161.000, tn 161.000
# Epoch 11 :: Val   loss 0.058, dice_lesion 0.002, dice_nonlesion 0.621, precision 0.001, recall 1.000, tp 697.000, fp 719223.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 12 :: learning rate 0.0001
# Epoch 12 :: Train loss 0.053, dice_lesion 0.040, dice_nonlesion 0.632, precision 0.021, recall 0.999, tp 106094.000, fp 4969463.000, fn 139.000, tn 139.000
# Epoch 12 :: Val   loss 0.054, dice_lesion 0.002, dice_nonlesion 0.629, precision 0.001, recall 1.000, tp 697.000, fp 708244.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 13 :: learning rate 0.0001
# Epoch 13 :: Train loss 0.049, dice_lesion 0.046, dice_nonlesion 0.640, precision 0.024, recall 0.999, tp 120820.000, fp 4878278.000, fn 121.000, tn 121.000
# Epoch 13 :: Val   loss 0.050, dice_lesion 0.002, dice_nonlesion 0.637, precision 0.001, recall 1.000, tp 697.000, fp 696872.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 14 :: learning rate 0.0001
# Epoch 14 :: Train loss 0.048, dice_lesion 0.042, dice_nonlesion 0.643, precision 0.023, recall 1.000, tp 112243.000, fp 4852725.000, fn 53.000, tn 53.000
# Epoch 14 :: Val   loss 0.047, dice_lesion 0.002, dice_nonlesion 0.645, precision 0.001, recall 1.000, tp 697.000, fp 685669.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 15 :: learning rate 0.0001
# Epoch 15 :: Train loss 0.044, dice_lesion 0.043, dice_nonlesion 0.654, precision 0.023, recall 1.000, tp 109865.000, fp 4736362.000, fn 40.000, tn 40.000
# Epoch 15 :: Val   loss 0.044, dice_lesion 0.002, dice_nonlesion 0.653, precision 0.001, recall 1.000, tp 697.000, fp 674172.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 16 :: learning rate 0.0001
# Epoch 16 :: Train loss 0.041, dice_lesion 0.043, dice_nonlesion 0.659, precision 0.023, recall 1.000, tp 112363.000, fp 4697762.000, fn 15.000, tn 15.000
# Epoch 16 :: Val   loss 0.041, dice_lesion 0.002, dice_nonlesion 0.661, precision 0.001, recall 1.000, tp 697.000, fp 662759.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 17 :: learning rate 0.0001
# Epoch 17 :: Train loss 0.039, dice_lesion 0.038, dice_nonlesion 0.670, precision 0.021, recall 1.000, tp 96432.000, fp 4580849.000, fn 6.000, tn 6.000
# Epoch 17 :: Val   loss 0.039, dice_lesion 0.002, dice_nonlesion 0.669, precision 0.001, recall 1.000, tp 697.000, fp 651160.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 18 :: learning rate 0.0001
# Epoch 18 :: Train loss 0.036, dice_lesion 0.047, dice_nonlesion 0.698, precision 0.026, recall 1.000, tp 112861.000, fp 4281873.000, fn 7.000, tn 7.000
# Epoch 18 :: Val   loss 0.036, dice_lesion 0.003, dice_nonlesion 0.762, precision 0.001, recall 1.000, tp 697.000, fp 503919.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 19 :: learning rate 0.0001
# Epoch 19 :: Train loss 0.033, dice_lesion 0.061, dice_nonlesion 0.775, precision 0.033, recall 1.000, tp 113863.000, fp 3388861.000, fn 4.000, tn 4.000
# Epoch 19 :: Val   loss 0.034, dice_lesion 0.003, dice_nonlesion 0.768, precision 0.001, recall 1.000, tp 697.000, fp 492144.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 20 :: learning rate 0.0001
# Epoch 20 :: Train loss 0.032, dice_lesion 0.050, dice_nonlesion 0.779, precision 0.026, recall 1.000, tp 88109.000, fp 3353891.000, fn 3.000, tn 3.000
# Epoch 20 :: Val   loss 0.032, dice_lesion 0.003, dice_nonlesion 0.775, precision 0.001, recall 1.000, tp 697.000, fp 480048.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 21 :: learning rate 0.0001
# Epoch 21 :: Train loss 0.030, dice_lesion 0.053, dice_nonlesion 0.786, precision 0.030, recall 1.000, tp 99533.000, fp 3252657.000, fn 5.000, tn 5.000
# Epoch 21 :: Val   loss 0.031, dice_lesion 0.003, dice_nonlesion 0.782, precision 0.001, recall 1.000, tp 697.000, fp 468077.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 22 :: learning rate 0.0001
# Epoch 22 :: Train loss 0.028, dice_lesion 0.060, dice_nonlesion 0.795, precision 0.031, recall 1.000, tp 100333.000, fp 3156094.000, fn 4.000, tn 4.000
# Epoch 22 :: Val   loss 0.029, dice_lesion 0.003, dice_nonlesion 0.789, precision 0.002, recall 1.000, tp 697.000, fp 456175.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 23 :: learning rate 0.0001
# Epoch 23 :: Train loss 0.027, dice_lesion 0.066, dice_nonlesion 0.799, precision 0.035, recall 1.000, tp 113126.000, fp 3085155.000, fn 5.000, tn 5.000
# Epoch 23 :: Val   loss 0.027, dice_lesion 0.003, dice_nonlesion 0.796, precision 0.002, recall 1.000, tp 697.000, fp 444089.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 24 :: learning rate 0.0001
# Epoch 24 :: Train loss 0.025, dice_lesion 0.065, dice_nonlesion 0.809, precision 0.035, recall 1.000, tp 106720.000, fp 2957949.000, fn 4.000, tn 4.000
# Epoch 24 :: Val   loss 0.026, dice_lesion 0.004, dice_nonlesion 0.802, precision 0.002, recall 1.000, tp 697.000, fp 432138.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 25 :: learning rate 0.0001
# Epoch 25 :: Train loss 0.025, dice_lesion 0.064, dice_nonlesion 0.815, precision 0.036, recall 1.000, tp 106758.000, fp 2874209.000, fn 4.000, tn 4.000
# Epoch 25 :: Val   loss 0.025, dice_lesion 0.004, dice_nonlesion 0.809, precision 0.002, recall 1.000, tp 697.000, fp 420463.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 26 :: learning rate 0.0001
# Epoch 26 :: Train loss 0.023, dice_lesion 0.074, dice_nonlesion 0.823, precision 0.043, recall 1.000, tp 122975.000, fp 2767382.000, fn 6.000, tn 6.000
# Epoch 26 :: Val   loss 0.024, dice_lesion 0.004, dice_nonlesion 0.815, precision 0.002, recall 1.000, tp 697.000, fp 408480.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 27 :: learning rate 0.0001
# Epoch 27 :: Train loss 0.022, dice_lesion 0.065, dice_nonlesion 0.829, precision 0.035, recall 1.000, tp 97380.000, fp 2695906.000, fn 4.000, tn 4.000
# Epoch 27 :: Val   loss 0.023, dice_lesion 0.004, dice_nonlesion 0.822, precision 0.002, recall 1.000, tp 697.000, fp 396367.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 28 :: learning rate 0.0001
# Epoch 28 :: Train loss 0.021, dice_lesion 0.064, dice_nonlesion 0.833, precision 0.035, recall 1.000, tp 95946.000, fp 2650920.000, fn 5.000, tn 5.000
# Epoch 28 :: Val   loss 0.022, dice_lesion 0.004, dice_nonlesion 0.828, precision 0.002, recall 1.000, tp 697.000, fp 384680.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 29 :: learning rate 0.0001
# Epoch 29 :: Train loss 0.020, dice_lesion 0.064, dice_nonlesion 0.839, precision 0.036, recall 1.000, tp 96113.000, fp 2556266.000, fn 3.000, tn 3.000
# Epoch 29 :: Val   loss 0.021, dice_lesion 0.004, dice_nonlesion 0.834, precision 0.002, recall 1.000, tp 697.000, fp 373074.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 30 :: learning rate 0.0001
# Epoch 30 :: Train loss 0.019, dice_lesion 0.075, dice_nonlesion 0.845, precision 0.042, recall 1.000, tp 109236.000, fp 2468716.000, fn 6.000, tn 6.000
# Epoch 30 :: Val   loss 0.020, dice_lesion 0.004, dice_nonlesion 0.840, precision 0.002, recall 1.000, tp 697.000, fp 361581.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 31 :: learning rate 0.0001
# Epoch 31 :: Train loss 0.018, dice_lesion 0.080, dice_nonlesion 0.853, precision 0.048, recall 1.000, tp 120319.000, fp 2372688.000, fn 6.000, tn 6.000
# Epoch 31 :: Val   loss 0.019, dice_lesion 0.004, dice_nonlesion 0.846, precision 0.002, recall 1.000, tp 697.000, fp 350050.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 32 :: learning rate 0.0001
# Epoch 32 :: Train loss 0.018, dice_lesion 0.074, dice_nonlesion 0.856, precision 0.042, recall 1.000, tp 101841.000, fp 2324676.000, fn 4.000, tn 4.000
# Epoch 32 :: Val   loss 0.018, dice_lesion 0.005, dice_nonlesion 0.851, precision 0.002, recall 1.000, tp 697.000, fp 338933.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 33 :: learning rate 0.0001
# Epoch 33 :: Train loss 0.018, dice_lesion 0.070, dice_nonlesion 0.860, precision 0.041, recall 1.000, tp 95423.000, fp 2260488.000, fn 3.000, tn 3.000
# Epoch 33 :: Val   loss 0.018, dice_lesion 0.005, dice_nonlesion 0.857, precision 0.002, recall 1.000, tp 697.000, fp 327602.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 34 :: learning rate 0.0001
# Epoch 34 :: Train loss 0.016, dice_lesion 0.098, dice_nonlesion 0.867, precision 0.056, recall 1.000, tp 127637.000, fp 2156431.000, fn 6.000, tn 6.000
# Epoch 34 :: Val   loss 0.017, dice_lesion 0.005, dice_nonlesion 0.863, precision 0.002, recall 1.000, tp 697.000, fp 316225.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 35 :: learning rate 0.0001
# Epoch 35 :: Train loss 0.016, dice_lesion 0.089, dice_nonlesion 0.873, precision 0.051, recall 1.000, tp 112045.000, fp 2082998.000, fn 4.000, tn 4.000
# Epoch 35 :: Val   loss 0.017, dice_lesion 0.005, dice_nonlesion 0.868, precision 0.002, recall 1.000, tp 697.000, fp 304997.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 36 :: learning rate 0.0001
# Epoch 36 :: Train loss 0.016, dice_lesion 0.080, dice_nonlesion 0.878, precision 0.045, recall 1.000, tp 94828.000, fp 2015849.000, fn 3.000, tn 3.000
# Epoch 36 :: Val   loss 0.016, dice_lesion 0.005, dice_nonlesion 0.873, precision 0.002, recall 1.000, tp 697.000, fp 294002.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 37 :: learning rate 0.0001
# Epoch 37 :: Train loss 0.015, dice_lesion 0.078, dice_nonlesion 0.884, precision 0.045, recall 1.000, tp 92007.000, fp 1930894.000, fn 3.000, tn 3.000
# Epoch 37 :: Val   loss 0.015, dice_lesion 0.006, dice_nonlesion 0.879, precision 0.002, recall 1.000, tp 697.000, fp 283196.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 38 :: learning rate 0.0001
# Epoch 38 :: Train loss 0.015, dice_lesion 0.077, dice_nonlesion 0.886, precision 0.043, recall 1.000, tp 85095.000, fp 1891523.000, fn 3.000, tn 3.000
# Epoch 38 :: Val   loss 0.015, dice_lesion 0.006, dice_nonlesion 0.884, precision 0.003, recall 1.000, tp 697.000, fp 272519.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 39 :: learning rate 0.0001
# Epoch 39 :: Train loss 0.014, dice_lesion 0.096, dice_nonlesion 0.894, precision 0.057, recall 1.000, tp 106961.000, fp 1768360.000, fn 4.000, tn 4.000
# Epoch 39 :: Val   loss 0.015, dice_lesion 0.006, dice_nonlesion 0.889, precision 0.003, recall 1.000, tp 697.000, fp 262515.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 40 :: learning rate 0.0001
# Epoch 40 :: Train loss 0.014, dice_lesion 0.095, dice_nonlesion 0.897, precision 0.057, recall 1.000, tp 103215.000, fp 1719333.000, fn 3.000, tn 3.000
# Epoch 40 :: Val   loss 0.014, dice_lesion 0.006, dice_nonlesion 0.893, precision 0.003, recall 1.000, tp 697.000, fp 252426.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 41 :: learning rate 0.0001
# Epoch 41 :: Train loss 0.013, dice_lesion 0.104, dice_nonlesion 0.899, precision 0.062, recall 1.000, tp 111445.000, fp 1681508.000, fn 6.000, tn 6.000
# Epoch 41 :: Val   loss 0.014, dice_lesion 0.007, dice_nonlesion 0.898, precision 0.003, recall 1.000, tp 697.000, fp 242737.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 42 :: learning rate 0.0001
# Epoch 42 :: Train loss 0.013, dice_lesion 0.100, dice_nonlesion 0.908, precision 0.059, recall 1.000, tp 98339.000, fp 1557405.000, fn 3.000, tn 3.000
# Epoch 42 :: Val   loss 0.013, dice_lesion 0.007, dice_nonlesion 0.902, precision 0.003, recall 1.000, tp 697.000, fp 233371.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 43 :: learning rate 0.0001
# Epoch 43 :: Train loss 0.012, dice_lesion 0.115, dice_nonlesion 0.911, precision 0.069, recall 1.000, tp 112095.000, fp 1502270.000, fn 4.000, tn 4.000
# Epoch 43 :: Val   loss 0.013, dice_lesion 0.007, dice_nonlesion 0.906, precision 0.003, recall 1.000, tp 697.000, fp 224120.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 44 :: learning rate 0.0001
# Epoch 44 :: Train loss 0.012, dice_lesion 0.108, dice_nonlesion 0.913, precision 0.068, recall 1.000, tp 107950.000, fp 1477631.000, fn 5.000, tn 5.000
# Epoch 44 :: Val   loss 0.013, dice_lesion 0.008, dice_nonlesion 0.910, precision 0.003, recall 1.000, tp 697.000, fp 215068.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 45 :: learning rate 0.0001
# Epoch 45 :: Train loss 0.012, dice_lesion 0.111, dice_nonlesion 0.917, precision 0.064, recall 1.000, tp 96290.000, fp 1409241.000, fn 3.000, tn 3.000
# Epoch 45 :: Val   loss 0.012, dice_lesion 0.008, dice_nonlesion 0.915, precision 0.003, recall 1.000, tp 697.000, fp 206107.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 46 :: learning rate 0.0001
# Epoch 46 :: Train loss 0.012, dice_lesion 0.128, dice_nonlesion 0.921, precision 0.081, recall 1.000, tp 118286.000, fp 1345665.000, fn 6.000, tn 6.000
# Epoch 46 :: Val   loss 0.012, dice_lesion 0.008, dice_nonlesion 0.918, precision 0.004, recall 1.000, tp 697.000, fp 197589.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 47 :: learning rate 0.0001
# Epoch 47 :: Train loss 0.011, dice_lesion 0.128, dice_nonlesion 0.924, precision 0.085, recall 1.000, tp 121034.000, fp 1304133.000, fn 6.000, tn 6.000
# Epoch 47 :: Val   loss 0.012, dice_lesion 0.009, dice_nonlesion 0.922, precision 0.004, recall 1.000, tp 697.000, fp 189111.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 48 :: learning rate 0.0001
# Epoch 48 :: Train loss 0.011, dice_lesion 0.143, dice_nonlesion 0.929, precision 0.089, recall 1.000, tp 119535.000, fp 1225525.000, fn 5.000, tn 5.000
# Epoch 48 :: Val   loss 0.011, dice_lesion 0.009, dice_nonlesion 0.926, precision 0.004, recall 1.000, tp 697.000, fp 181010.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 49 :: learning rate 0.0001
# Epoch 49 :: Train loss 0.011, dice_lesion 0.117, dice_nonlesion 0.930, precision 0.074, recall 1.000, tp 95830.000, fp 1204019.000, fn 3.000, tn 3.000
# Epoch 49 :: Val   loss 0.011, dice_lesion 0.010, dice_nonlesion 0.929, precision 0.004, recall 1.000, tp 697.000, fp 173129.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 50 :: learning rate 0.0001
# Epoch 50 :: Train loss 0.011, dice_lesion 0.143, dice_nonlesion 0.934, precision 0.091, recall 1.000, tp 115165.000, fp 1147087.000, fn 4.000, tn 4.000
# Epoch 50 :: Val   loss 0.011, dice_lesion 0.010, dice_nonlesion 0.932, precision 0.004, recall 1.000, tp 697.000, fp 165627.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 51 :: learning rate 0.0001
# Epoch 51 :: Train loss 0.010, dice_lesion 0.124, dice_nonlesion 0.938, precision 0.080, recall 1.000, tp 93492.000, fp 1078218.000, fn 3.000, tn 3.000
# Epoch 51 :: Val   loss 0.011, dice_lesion 0.011, dice_nonlesion 0.936, precision 0.004, recall 1.000, tp 697.000, fp 158108.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 52 :: learning rate 0.0001
# Epoch 52 :: Train loss 0.010, dice_lesion 0.148, dice_nonlesion 0.939, precision 0.094, recall 1.000, tp 110191.000, fp 1059597.000, fn 6.000, tn 6.000
# Epoch 52 :: Val   loss 0.011, dice_lesion 0.011, dice_nonlesion 0.939, precision 0.005, recall 1.000, tp 697.000, fp 151060.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 53 :: learning rate 0.0001
# Epoch 53 :: Train loss 0.010, dice_lesion 0.164, dice_nonlesion 0.944, precision 0.104, recall 1.000, tp 113858.000, fp 983640.000, fn 6.000, tn 6.000
# Epoch 53 :: Val   loss 0.010, dice_lesion 0.012, dice_nonlesion 0.942, precision 0.005, recall 1.000, tp 697.000, fp 144228.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 54 :: learning rate 0.0001
# Epoch 54 :: Train loss 0.010, dice_lesion 0.131, dice_nonlesion 0.946, precision 0.085, recall 1.000, tp 88429.000, fp 945978.000, fn 3.000, tn 3.000
# Epoch 54 :: Val   loss 0.010, dice_lesion 0.012, dice_nonlesion 0.944, precision 0.005, recall 1.000, tp 697.000, fp 137681.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 55 :: learning rate 0.0001
# Epoch 55 :: Train loss 0.009, dice_lesion 0.164, dice_nonlesion 0.949, precision 0.108, recall 1.000, tp 107389.000, fp 890793.000, fn 4.000, tn 4.000
# Epoch 55 :: Val   loss 0.010, dice_lesion 0.013, dice_nonlesion 0.947, precision 0.005, recall 1.000, tp 697.000, fp 131549.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 56 :: learning rate 0.0001
# Epoch 56 :: Train loss 0.009, dice_lesion 0.158, dice_nonlesion 0.950, precision 0.104, recall 1.000, tp 101574.000, fp 870819.000, fn 4.000, tn 4.000
# Epoch 56 :: Val   loss 0.010, dice_lesion 0.013, dice_nonlesion 0.950, precision 0.006, recall 1.000, tp 697.000, fp 125547.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 57 :: learning rate 0.0001
# Epoch 57 :: Train loss 0.009, dice_lesion 0.177, dice_nonlesion 0.953, precision 0.112, recall 1.000, tp 103929.000, fp 824466.000, fn 2.000, tn 2.000
# Epoch 57 :: Val   loss 0.010, dice_lesion 0.014, dice_nonlesion 0.952, precision 0.006, recall 1.000, tp 697.000, fp 119711.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 58 :: learning rate 0.0001
# Epoch 58 :: Train loss 0.009, dice_lesion 0.157, dice_nonlesion 0.955, precision 0.099, recall 1.000, tp 88064.000, fp 799107.000, fn 2.000, tn 2.000
# Epoch 58 :: Val   loss 0.009, dice_lesion 0.014, dice_nonlesion 0.955, precision 0.006, recall 1.000, tp 697.000, fp 113942.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 59 :: learning rate 0.0001
# Epoch 59 :: Train loss 0.009, dice_lesion 0.199, dice_nonlesion 0.957, precision 0.136, recall 1.000, tp 118028.000, fp 752536.000, fn 3.000, tn 3.000
# Epoch 59 :: Val   loss 0.009, dice_lesion 0.015, dice_nonlesion 0.957, precision 0.006, recall 1.000, tp 697.000, fp 108391.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 60 :: learning rate 0.0001
# Epoch 60 :: Train loss 0.009, dice_lesion 0.217, dice_nonlesion 0.960, precision 0.150, recall 1.000, tp 126324.000, fp 713525.000, fn 4.000, tn 4.000
# Epoch 60 :: Val   loss 0.009, dice_lesion 0.015, dice_nonlesion 0.959, precision 0.007, recall 1.000, tp 697.000, fp 103020.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 61 :: learning rate 0.0001
# Epoch 61 :: Train loss 0.008, dice_lesion 0.210, dice_nonlesion 0.963, precision 0.145, recall 1.000, tp 111827.000, fp 661555.000, fn 3.000, tn 3.000
# Epoch 61 :: Val   loss 0.009, dice_lesion 0.016, dice_nonlesion 0.961, precision 0.007, recall 1.000, tp 697.000, fp 98161.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 62 :: learning rate 0.0001
# Epoch 62 :: Train loss 0.008, dice_lesion 0.174, dice_nonlesion 0.965, precision 0.119, recall 1.000, tp 85253.000, fp 632937.000, fn 2.000, tn 2.000
# Epoch 62 :: Val   loss 0.009, dice_lesion 0.017, dice_nonlesion 0.963, precision 0.007, recall 1.000, tp 697.000, fp 93525.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 63 :: learning rate 0.0001
# Epoch 63 :: Train loss 0.008, dice_lesion 0.170, dice_nonlesion 0.967, precision 0.131, recall 1.000, tp 90146.000, fp 596228.000, fn 2.000, tn 2.000
# Epoch 63 :: Val   loss 0.009, dice_lesion 0.017, dice_nonlesion 0.965, precision 0.008, recall 1.000, tp 697.000, fp 89191.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 64 :: learning rate 0.0001
# Epoch 64 :: Train loss 0.008, dice_lesion 0.254, dice_nonlesion 0.968, precision 0.181, recall 1.000, tp 125789.000, fp 570339.000, fn 4.000, tn 4.000
# Epoch 64 :: Val   loss 0.008, dice_lesion 0.018, dice_nonlesion 0.966, precision 0.008, recall 1.000, tp 697.000, fp 85006.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 65 :: learning rate 0.0001
# Epoch 65 :: Train loss 0.008, dice_lesion 0.228, dice_nonlesion 0.969, precision 0.174, recall 1.000, tp 115304.000, fp 548522.000, fn 3.000, tn 3.000
# Epoch 65 :: Val   loss 0.008, dice_lesion 0.019, dice_nonlesion 0.968, precision 0.009, recall 1.000, tp 697.000, fp 80962.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 66 :: learning rate 0.0001
# Epoch 66 :: Train loss 0.008, dice_lesion 0.216, dice_nonlesion 0.971, precision 0.160, recall 1.000, tp 99495.000, fp 522742.000, fn 3.000, tn 3.000
# Epoch 66 :: Val   loss 0.008, dice_lesion 0.019, dice_nonlesion 0.970, precision 0.009, recall 1.000, tp 697.000, fp 76960.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 67 :: learning rate 0.0001
# Epoch 67 :: Train loss 0.008, dice_lesion 0.218, dice_nonlesion 0.972, precision 0.162, recall 1.000, tp 96109.000, fp 498874.000, fn 2.000, tn 2.000
# Epoch 67 :: Val   loss 0.008, dice_lesion 0.020, dice_nonlesion 0.971, precision 0.009, recall 1.000, tp 697.000, fp 73339.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 68 :: learning rate 0.0001
# Epoch 68 :: Train loss 0.008, dice_lesion 0.218, dice_nonlesion 0.974, precision 0.170, recall 1.000, tp 97935.000, fp 478504.000, fn 3.000, tn 3.000
# Epoch 68 :: Val   loss 0.008, dice_lesion 0.021, dice_nonlesion 0.973, precision 0.010, recall 1.000, tp 697.000, fp 69742.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 69 :: learning rate 0.0001
# Epoch 69 :: Train loss 0.007, dice_lesion 0.228, dice_nonlesion 0.976, precision 0.212, recall 1.000, tp 115321.000, fp 429923.000, fn 3.000, tn 3.000
# Epoch 69 :: Val   loss 0.008, dice_lesion 0.022, dice_nonlesion 0.974, precision 0.010, recall 1.000, tp 697.000, fp 66296.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 70 :: learning rate 0.0001
# Epoch 70 :: Train loss 0.007, dice_lesion 0.248, dice_nonlesion 0.976, precision 0.205, recall 1.000, tp 113851.000, fp 441724.000, fn 4.000, tn 4.000
# Epoch 70 :: Val   loss 0.008, dice_lesion 0.023, dice_nonlesion 0.975, precision 0.011, recall 1.000, tp 697.000, fp 63125.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 71 :: learning rate 0.0001
# Epoch 71 :: Train loss 0.007, dice_lesion 0.261, dice_nonlesion 0.977, precision 0.206, recall 1.000, tp 106158.000, fp 409338.000, fn 3.000, tn 3.000
# Epoch 71 :: Val   loss 0.008, dice_lesion 0.023, dice_nonlesion 0.977, precision 0.011, recall 1.000, tp 697.000, fp 60125.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 72 :: learning rate 0.0001
# Epoch 72 :: Train loss 0.007, dice_lesion 0.312, dice_nonlesion 0.979, precision 0.245, recall 1.000, tp 123239.000, fp 379914.000, fn 4.000, tn 4.000
# Epoch 72 :: Val   loss 0.008, dice_lesion 0.024, dice_nonlesion 0.978, precision 0.012, recall 1.000, tp 697.000, fp 57244.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 73 :: learning rate 0.0001
# Epoch 73 :: Train loss 0.007, dice_lesion 0.255, dice_nonlesion 0.980, precision 0.211, recall 1.000, tp 97404.000, fp 363363.000, fn 2.000, tn 2.000
# Epoch 73 :: Val   loss 0.007, dice_lesion 0.025, dice_nonlesion 0.979, precision 0.013, recall 1.000, tp 697.000, fp 54393.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 74 :: learning rate 0.0001
# Epoch 74 :: Train loss 0.007, dice_lesion 0.286, dice_nonlesion 0.981, precision 0.251, recall 1.000, tp 112668.000, fp 335454.000, fn 5.000, tn 5.000
# Epoch 74 :: Val   loss 0.007, dice_lesion 0.027, dice_nonlesion 0.980, precision 0.013, recall 1.000, tp 697.000, fp 51742.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 75 :: learning rate 0.0001
# Epoch 75 :: Train loss 0.007, dice_lesion 0.249, dice_nonlesion 0.981, precision 0.202, recall 1.000, tp 85537.000, fp 337731.000, fn 3.000, tn 3.000
# Epoch 75 :: Val   loss 0.007, dice_lesion 0.028, dice_nonlesion 0.981, precision 0.014, recall 1.000, tp 697.000, fp 49163.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 76 :: learning rate 0.0001
# Epoch 76 :: Train loss 0.007, dice_lesion 0.304, dice_nonlesion 0.983, precision 0.250, recall 1.000, tp 103704.000, fp 310556.000, fn 4.000, tn 4.000
# Epoch 76 :: Val   loss 0.007, dice_lesion 0.029, dice_nonlesion 0.982, precision 0.015, recall 1.000, tp 697.000, fp 46724.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 77 :: learning rate 0.0001
# Epoch 77 :: Train loss 0.007, dice_lesion 0.300, dice_nonlesion 0.983, precision 0.267, recall 1.000, tp 109452.000, fp 301101.000, fn 5.000, tn 5.000
# Epoch 77 :: Val   loss 0.007, dice_lesion 0.030, dice_nonlesion 0.983, precision 0.015, recall 1.000, tp 697.000, fp 44521.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 78 :: learning rate 0.0001
# Epoch 78 :: Train loss 0.007, dice_lesion 0.291, dice_nonlesion 0.985, precision 0.287, recall 1.000, tp 110478.000, fp 274135.000, fn 5.000, tn 5.000
# Epoch 78 :: Val   loss 0.007, dice_lesion 0.031, dice_nonlesion 0.984, precision 0.016, recall 1.000, tp 697.000, fp 42346.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 79 :: learning rate 0.0001
# Epoch 79 :: Train loss 0.007, dice_lesion 0.363, dice_nonlesion 0.986, precision 0.319, recall 1.000, tp 120214.000, fp 256756.000, fn 5.000, tn 5.000
# Epoch 79 :: Val   loss 0.007, dice_lesion 0.032, dice_nonlesion 0.984, precision 0.017, recall 1.000, tp 697.000, fp 40267.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 80 :: learning rate 0.0001
# Epoch 80 :: Train loss 0.006, dice_lesion 0.300, dice_nonlesion 0.986, precision 0.296, recall 1.000, tp 103902.000, fp 246789.000, fn 5.000, tn 5.000
# Epoch 80 :: Val   loss 0.007, dice_lesion 0.034, dice_nonlesion 0.985, precision 0.018, recall 1.000, tp 697.000, fp 38409.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 81 :: learning rate 0.0001
# Epoch 81 :: Train loss 0.006, dice_lesion 0.339, dice_nonlesion 0.987, precision 0.275, recall 1.000, tp 92422.000, fp 243729.000, fn 4.000, tn 4.000
# Epoch 81 :: Val   loss 0.007, dice_lesion 0.035, dice_nonlesion 0.986, precision 0.019, recall 1.000, tp 697.000, fp 36601.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 82 :: learning rate 0.0001
# Epoch 82 :: Train loss 0.006, dice_lesion 0.302, dice_nonlesion 0.987, precision 0.302, recall 1.000, tp 100652.000, fp 232986.000, fn 5.000, tn 5.000
# Epoch 82 :: Val   loss 0.007, dice_lesion 0.036, dice_nonlesion 0.986, precision 0.020, recall 1.000, tp 697.000, fp 34914.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 83 :: learning rate 0.0001
# Epoch 83 :: Train loss 0.006, dice_lesion 0.318, dice_nonlesion 0.988, precision 0.311, recall 1.000, tp 95610.000, fp 211893.000, fn 6.000, tn 6.000
# Epoch 83 :: Val   loss 0.007, dice_lesion 0.038, dice_nonlesion 0.987, precision 0.021, recall 1.000, tp 697.000, fp 33181.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 84 :: learning rate 0.0001
# Epoch 84 :: Train loss 0.006, dice_lesion 0.323, dice_nonlesion 0.989, precision 0.326, recall 1.000, tp 97092.000, fp 201131.000, fn 7.000, tn 7.000
# Epoch 84 :: Val   loss 0.006, dice_lesion 0.039, dice_nonlesion 0.988, precision 0.022, recall 1.000, tp 697.000, fp 31549.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 85 :: learning rate 0.0001
# Epoch 85 :: Train loss 0.006, dice_lesion 0.398, dice_nonlesion 0.990, precision 0.403, recall 1.000, tp 124674.000, fp 184820.000, fn 8.000, tn 8.000
# Epoch 85 :: Val   loss 0.006, dice_lesion 0.041, dice_nonlesion 0.988, precision 0.023, recall 1.000, tp 697.000, fp 29981.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 86 :: learning rate 0.0001
# Epoch 86 :: Train loss 0.006, dice_lesion 0.366, dice_nonlesion 0.990, precision 0.376, recall 1.000, tp 107585.000, fp 178272.000, fn 7.000, tn 7.000
# Epoch 86 :: Val   loss 0.006, dice_lesion 0.042, dice_nonlesion 0.989, precision 0.024, recall 1.000, tp 697.000, fp 28542.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 87 :: learning rate 0.0001
# Epoch 87 :: Train loss 0.006, dice_lesion 0.327, dice_nonlesion 0.991, precision 0.334, recall 1.000, tp 83785.000, fp 166988.000, fn 5.000, tn 5.000
# Epoch 87 :: Val   loss 0.006, dice_lesion 0.044, dice_nonlesion 0.990, precision 0.025, recall 1.000, tp 697.000, fp 27098.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 88 :: learning rate 0.0001
# Epoch 88 :: Train loss 0.006, dice_lesion 0.428, dice_nonlesion 0.991, precision 0.426, recall 1.000, tp 122821.000, fp 165646.000, fn 10.000, tn 10.000
# Epoch 88 :: Val   loss 0.006, dice_lesion 0.046, dice_nonlesion 0.990, precision 0.026, recall 1.000, tp 697.000, fp 25719.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 89 :: learning rate 0.0001
# Epoch 89 :: Train loss 0.006, dice_lesion 0.426, dice_nonlesion 0.992, precision 0.417, recall 1.000, tp 109875.000, fp 153443.000, fn 8.000, tn 8.000
# Epoch 89 :: Val   loss 0.006, dice_lesion 0.048, dice_nonlesion 0.991, precision 0.028, recall 1.000, tp 697.000, fp 24376.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 90 :: learning rate 0.0001
# Epoch 90 :: Train loss 0.006, dice_lesion 0.417, dice_nonlesion 0.993, precision 0.434, recall 1.000, tp 102773.000, fp 134149.000, fn 6.000, tn 6.000
# Epoch 90 :: Val   loss 0.006, dice_lesion 0.049, dice_nonlesion 0.991, precision 0.029, recall 1.000, tp 697.000, fp 23094.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 91 :: learning rate 0.0001
# Epoch 91 :: Train loss 0.006, dice_lesion 0.446, dice_nonlesion 0.992, precision 0.453, recall 1.000, tp 114099.000, fp 137888.000, fn 10.000, tn 10.000
# Epoch 91 :: Val   loss 0.006, dice_lesion 0.051, dice_nonlesion 0.992, precision 0.031, recall 1.000, tp 697.000, fp 21975.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 92 :: learning rate 0.0001
# Epoch 92 :: Train loss 0.006, dice_lesion 0.395, dice_nonlesion 0.993, precision 0.404, recall 1.000, tp 91532.000, fp 135120.000, fn 8.000, tn 8.000
# Epoch 92 :: Val   loss 0.006, dice_lesion 0.053, dice_nonlesion 0.992, precision 0.032, recall 1.000, tp 697.000, fp 20800.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 93 :: learning rate 0.0001
# Epoch 93 :: Train loss 0.006, dice_lesion 0.483, dice_nonlesion 0.994, precision 0.513, recall 1.000, tp 122329.000, fp 115971.000, fn 11.000, tn 11.000
# Epoch 93 :: Val   loss 0.006, dice_lesion 0.055, dice_nonlesion 0.992, precision 0.034, recall 1.000, tp 697.000, fp 19674.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 94 :: learning rate 0.0001
# Epoch 94 :: Train loss 0.006, dice_lesion 0.407, dice_nonlesion 0.994, precision 0.436, recall 1.000, tp 92334.000, fp 119335.000, fn 7.000, tn 7.000
# Epoch 94 :: Val   loss 0.006, dice_lesion 0.057, dice_nonlesion 0.993, precision 0.036, recall 1.000, tp 697.000, fp 18568.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 95 :: learning rate 0.0001
# Epoch 95 :: Train loss 0.005, dice_lesion 0.502, dice_nonlesion 0.994, precision 0.518, recall 1.000, tp 118381.000, fp 110265.000, fn 11.000, tn 11.000
# Epoch 95 :: Val   loss 0.006, dice_lesion 0.059, dice_nonlesion 0.993, precision 0.038, recall 1.000, tp 697.000, fp 17615.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 96 :: learning rate 0.0001
# Epoch 96 :: Train loss 0.005, dice_lesion 0.487, dice_nonlesion 0.994, precision 0.467, recall 1.000, tp 91443.000, fp 104524.000, fn 6.000, tn 6.000
# Epoch 96 :: Val   loss 0.006, dice_lesion 0.061, dice_nonlesion 0.994, precision 0.040, recall 1.000, tp 697.000, fp 16670.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 97 :: learning rate 0.0001
# Epoch 97 :: Train loss 0.005, dice_lesion 0.472, dice_nonlesion 0.994, precision 0.491, recall 1.000, tp 99012.000, fp 102523.000, fn 6.000, tn 6.000
# Epoch 97 :: Val   loss 0.006, dice_lesion 0.063, dice_nonlesion 0.994, precision 0.043, recall 1.000, tp 697.000, fp 15702.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 98 :: learning rate 0.0001
# Epoch 98 :: Train loss 0.005, dice_lesion 0.429, dice_nonlesion 0.995, precision 0.517, recall 1.000, tp 94172.000, fp 87974.000, fn 8.000, tn 8.000
# Epoch 98 :: Val   loss 0.006, dice_lesion 0.065, dice_nonlesion 0.994, precision 0.045, recall 1.000, tp 697.000, fp 14874.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 99 :: learning rate 0.0001
# Epoch 99 :: Train loss 0.005, dice_lesion 0.463, dice_nonlesion 0.995, precision 0.542, recall 1.000, tp 109158.000, fp 92296.000, fn 9.000, tn 9.000
# Epoch 99 :: Val   loss 0.006, dice_lesion 0.067, dice_nonlesion 0.995, precision 0.047, recall 1.000, tp 697.000, fp 14172.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 100 :: learning rate 0.0001
# Epoch 100 :: Train loss 0.005, dice_lesion 0.508, dice_nonlesion 0.995, precision 0.573, recall 1.000, tp 110773.000, fp 82559.000, fn 10.000, tn 10.000
# Epoch 100 :: Val   loss 0.005, dice_lesion 0.069, dice_nonlesion 0.995, precision 0.049, recall 1.000, tp 697.000, fp 13469.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 101 :: learning rate 0.0001
# Epoch 101 :: Train loss 0.005, dice_lesion 0.452, dice_nonlesion 0.996, precision 0.585, recall 1.000, tp 111746.000, fp 79352.000, fn 13.000, tn 13.000
# Epoch 101 :: Val   loss 0.005, dice_lesion 0.072, dice_nonlesion 0.995, precision 0.052, recall 1.000, tp 697.000, fp 12831.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 102 :: learning rate 0.0001
# Epoch 102 :: Train loss 0.005, dice_lesion 0.509, dice_nonlesion 0.996, precision 0.529, recall 1.000, tp 85587.000, fp 76311.000, fn 7.000, tn 7.000
# Epoch 102 :: Val   loss 0.005, dice_lesion 0.074, dice_nonlesion 0.995, precision 0.054, recall 1.000, tp 697.000, fp 12215.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 103 :: learning rate 0.0001
# Epoch 103 :: Train loss 0.005, dice_lesion 0.515, dice_nonlesion 0.996, precision 0.618, recall 1.000, tp 117319.000, fp 72489.000, fn 15.000, tn 15.000
# Epoch 103 :: Val   loss 0.005, dice_lesion 0.077, dice_nonlesion 0.996, precision 0.056, recall 1.000, tp 697.000, fp 11668.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 104 :: learning rate 0.0001
# Epoch 104 :: Train loss 0.005, dice_lesion 0.508, dice_nonlesion 0.997, precision 0.626, recall 1.000, tp 108744.000, fp 64858.000, fn 14.000, tn 14.000
# Epoch 104 :: Val   loss 0.005, dice_lesion 0.079, dice_nonlesion 0.996, precision 0.059, recall 1.000, tp 697.000, fp 11109.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 105 :: learning rate 0.0001
# Epoch 105 :: Train loss 0.005, dice_lesion 0.567, dice_nonlesion 0.996, precision 0.651, recall 1.000, tp 121760.000, fp 65263.000, fn 16.000, tn 16.000
# Epoch 105 :: Val   loss 0.005, dice_lesion 0.082, dice_nonlesion 0.996, precision 0.062, recall 1.000, tp 697.000, fp 10618.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 106 :: learning rate 0.0001
# Epoch 106 :: Train loss 0.005, dice_lesion 0.575, dice_nonlesion 0.997, precision 0.672, recall 1.000, tp 126532.000, fp 61886.000, fn 16.000, tn 16.000
# Epoch 106 :: Val   loss 0.005, dice_lesion 0.084, dice_nonlesion 0.996, precision 0.064, recall 1.000, tp 697.000, fp 10173.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 107 :: learning rate 0.0001
# Epoch 107 :: Train loss 0.005, dice_lesion 0.578, dice_nonlesion 0.997, precision 0.668, recall 1.000, tp 103774.000, fp 51583.000, fn 11.000, tn 11.000
# Epoch 107 :: Val   loss 0.005, dice_lesion 0.087, dice_nonlesion 0.996, precision 0.067, recall 1.000, tp 697.000, fp 9705.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 108 :: learning rate 0.0001
# Epoch 108 :: Train loss 0.005, dice_lesion 0.628, dice_nonlesion 0.997, precision 0.666, recall 1.000, tp 104691.000, fp 52467.000, fn 13.000, tn 13.000
# Epoch 108 :: Val   loss 0.005, dice_lesion 0.090, dice_nonlesion 0.996, precision 0.070, recall 1.000, tp 697.000, fp 9263.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 109 :: learning rate 0.0001
# Epoch 109 :: Train loss 0.005, dice_lesion 0.465, dice_nonlesion 0.997, precision 0.655, recall 1.000, tp 96245.000, fp 50658.000, fn 13.000, tn 13.000
# Epoch 109 :: Val   loss 0.005, dice_lesion 0.093, dice_nonlesion 0.997, precision 0.073, recall 1.000, tp 697.000, fp 8829.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 110 :: learning rate 0.0001
# Epoch 110 :: Train loss 0.005, dice_lesion 0.631, dice_nonlesion 0.997, precision 0.731, recall 1.000, tp 129684.000, fp 47620.000, fn 16.000, tn 16.000
# Epoch 110 :: Val   loss 0.005, dice_lesion 0.096, dice_nonlesion 0.997, precision 0.076, recall 1.000, tp 697.000, fp 8424.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 111 :: learning rate 0.0001
# Epoch 111 :: Train loss 0.005, dice_lesion 0.513, dice_nonlesion 0.997, precision 0.674, recall 1.000, tp 104074.000, fp 50248.000, fn 14.000, tn 14.000
# Epoch 111 :: Val   loss 0.005, dice_lesion 0.098, dice_nonlesion 0.997, precision 0.079, recall 1.000, tp 697.000, fp 8084.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 112 :: learning rate 0.0001
# Epoch 112 :: Train loss 0.005, dice_lesion 0.521, dice_nonlesion 0.998, precision 0.679, recall 1.000, tp 91841.000, fp 43413.000, fn 9.000, tn 9.000
# Epoch 112 :: Val   loss 0.005, dice_lesion 0.101, dice_nonlesion 0.997, precision 0.083, recall 1.000, tp 697.000, fp 7734.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 113 :: learning rate 0.0001
# Epoch 113 :: Train loss 0.005, dice_lesion 0.529, dice_nonlesion 0.998, precision 0.682, recall 1.000, tp 93180.000, fp 43353.000, fn 10.000, tn 10.000
# Epoch 113 :: Val   loss 0.005, dice_lesion 0.103, dice_nonlesion 0.997, precision 0.086, recall 1.000, tp 697.000, fp 7402.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 114 :: learning rate 0.0001
# Epoch 114 :: Train loss 0.005, dice_lesion 0.510, dice_nonlesion 0.998, precision 0.657, recall 1.000, tp 78565.000, fp 41018.000, fn 8.000, tn 8.000
# Epoch 114 :: Val   loss 0.005, dice_lesion 0.106, dice_nonlesion 0.997, precision 0.090, recall 1.000, tp 697.000, fp 7081.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 115 :: learning rate 0.0001
# Epoch 115 :: Train loss 0.005, dice_lesion 0.563, dice_nonlesion 0.998, precision 0.746, recall 1.000, tp 102179.000, fp 34725.000, fn 13.000, tn 13.000
# Epoch 115 :: Val   loss 0.005, dice_lesion 0.108, dice_nonlesion 0.997, precision 0.093, recall 1.000, tp 697.000, fp 6783.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 116 :: learning rate 0.0001
# Epoch 116 :: Train loss 0.005, dice_lesion 0.610, dice_nonlesion 0.998, precision 0.769, recall 1.000, tp 123830.000, fp 37115.000, fn 18.000, tn 18.000
# Epoch 116 :: Val   loss 0.005, dice_lesion 0.110, dice_nonlesion 0.998, precision 0.096, recall 1.000, tp 697.000, fp 6528.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 117 :: learning rate 0.0001
# Epoch 117 :: Train loss 0.004, dice_lesion 0.605, dice_nonlesion 0.998, precision 0.741, recall 1.000, tp 91383.000, fp 31930.000, fn 11.000, tn 11.000
# Epoch 117 :: Val   loss 0.005, dice_lesion 0.113, dice_nonlesion 0.998, precision 0.100, recall 1.000, tp 697.000, fp 6283.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 118 :: learning rate 0.0001
# Epoch 118 :: Train loss 0.005, dice_lesion 0.678, dice_nonlesion 0.998, precision 0.782, recall 1.000, tp 108054.000, fp 30055.000, fn 15.000, tn 15.000
# Epoch 118 :: Val   loss 0.005, dice_lesion 0.115, dice_nonlesion 0.998, precision 0.103, recall 1.000, tp 697.000, fp 6042.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 119 :: learning rate 0.0001
# Epoch 119 :: Train loss 0.004, dice_lesion 0.595, dice_nonlesion 0.998, precision 0.799, recall 1.000, tp 116669.000, fp 29363.000, fn 16.000, tn 16.000
# Epoch 119 :: Val   loss 0.005, dice_lesion 0.118, dice_nonlesion 0.998, precision 0.107, recall 1.000, tp 697.000, fp 5796.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 120 :: learning rate 0.0001
# Epoch 120 :: Train loss 0.004, dice_lesion 0.621, dice_nonlesion 0.998, precision 0.789, recall 1.000, tp 119054.000, fp 31761.000, fn 17.000, tn 17.000
# Epoch 120 :: Val   loss 0.005, dice_lesion 0.120, dice_nonlesion 0.998, precision 0.111, recall 1.000, tp 697.000, fp 5556.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 121 :: learning rate 0.0001
# Epoch 121 :: Train loss 0.004, dice_lesion 0.571, dice_nonlesion 0.998, precision 0.784, recall 1.000, tp 100615.000, fp 27681.000, fn 12.000, tn 12.000
# Epoch 121 :: Val   loss 0.005, dice_lesion 0.123, dice_nonlesion 0.998, precision 0.116, recall 1.000, tp 697.000, fp 5322.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 122 :: learning rate 0.0001
# Epoch 122 :: Train loss 0.004, dice_lesion 0.669, dice_nonlesion 0.999, precision 0.797, recall 1.000, tp 99289.000, fp 25213.000, fn 10.000, tn 10.000
# Epoch 122 :: Val   loss 0.005, dice_lesion 0.125, dice_nonlesion 0.998, precision 0.119, recall 1.000, tp 697.000, fp 5137.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 123 :: learning rate 0.0001
# Epoch 123 :: Train loss 0.004, dice_lesion 0.624, dice_nonlesion 0.999, precision 0.787, recall 1.000, tp 87580.000, fp 23701.000, fn 9.000, tn 9.000
# Epoch 123 :: Val   loss 0.005, dice_lesion 0.128, dice_nonlesion 0.998, precision 0.123, recall 1.000, tp 697.000, fp 4954.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 124 :: learning rate 0.0001
# Epoch 124 :: Train loss 0.004, dice_lesion 0.674, dice_nonlesion 0.999, precision 0.813, recall 1.000, tp 107569.000, fp 24808.000, fn 15.000, tn 15.000
# Epoch 124 :: Val   loss 0.004, dice_lesion 0.130, dice_nonlesion 0.998, precision 0.127, recall 1.000, tp 697.000, fp 4788.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 125 :: learning rate 0.0001
# Epoch 125 :: Train loss 0.004, dice_lesion 0.591, dice_nonlesion 0.999, precision 0.830, recall 1.000, tp 96891.000, fp 19910.000, fn 10.000, tn 10.000
# Epoch 125 :: Val   loss 0.004, dice_lesion 0.132, dice_nonlesion 0.998, precision 0.132, recall 1.000, tp 697.000, fp 4600.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 126 :: learning rate 0.0001
# Epoch 126 :: Train loss 0.004, dice_lesion 0.615, dice_nonlesion 0.999, precision 0.806, recall 1.000, tp 95666.000, fp 23017.000, fn 11.000, tn 11.000
# Epoch 126 :: Val   loss 0.004, dice_lesion 0.134, dice_nonlesion 0.998, precision 0.135, recall 1.000, tp 697.000, fp 4464.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 127 :: learning rate 0.0001
# Epoch 127 :: Train loss 0.004, dice_lesion 0.665, dice_nonlesion 0.999, precision 0.818, recall 1.000, tp 105921.000, fp 23585.000, fn 14.000, tn 14.000
# Epoch 127 :: Val   loss 0.004, dice_lesion 0.136, dice_nonlesion 0.998, precision 0.139, recall 1.000, tp 697.000, fp 4329.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 128 :: learning rate 0.0001
# Epoch 128 :: Train loss 0.004, dice_lesion 0.610, dice_nonlesion 0.999, precision 0.831, recall 1.000, tp 106214.000, fp 21645.000, fn 14.000, tn 14.000
# Epoch 128 :: Val   loss 0.004, dice_lesion 0.139, dice_nonlesion 0.998, precision 0.143, recall 1.000, tp 697.000, fp 4185.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 129 :: learning rate 0.0001
# Epoch 129 :: Train loss 0.004, dice_lesion 0.641, dice_nonlesion 0.999, precision 0.854, recall 1.000, tp 106549.000, fp 18260.000, fn 17.000, tn 17.000
# Epoch 129 :: Val   loss 0.004, dice_lesion 0.141, dice_nonlesion 0.998, precision 0.148, recall 1.000, tp 697.000, fp 4025.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 130 :: learning rate 0.0001
# ...
# saved_new_best
# Epoch 354 :: learning rate 0.0001
# Epoch 354 :: Train loss 0.002, dice_lesion 0.827, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 111360.000, fp 12.000, fn 166.000, tn 166.000
# Epoch 354 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 355 :: learning rate 0.0001
# Epoch 355 :: Train loss 0.002, dice_lesion 0.793, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 115037.000, fp 12.000, fn 171.000, tn 171.000
# Epoch 355 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 356 :: learning rate 0.0001
# Epoch 356 :: Train loss 0.002, dice_lesion 0.689, dice_nonlesion 1.000, precision 0.998, recall 0.999, tp 89981.000, fp 141.000, fn 100.000, tn 100.000
# Epoch 356 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 357 :: learning rate 0.0001
# Epoch 357 :: Train loss 0.002, dice_lesion 0.793, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 129701.000, fp 12.000, fn 175.000, tn 175.000
# Epoch 357 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 358 :: learning rate 0.0001
# Epoch 358 :: Train loss 0.002, dice_lesion 0.621, dice_nonlesion 1.000, precision 0.999, recall 0.999, tp 102806.000, fp 110.000, fn 103.000, tn 103.000
# Epoch 358 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 359 :: learning rate 0.0001
# Epoch 359 :: Train loss 0.002, dice_lesion 0.827, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 100620.000, fp 8.000, fn 101.000, tn 101.000
# Epoch 359 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 360 :: learning rate 0.0001
# Epoch 360 :: Train loss 0.002, dice_lesion 0.724, dice_nonlesion 1.000, precision 0.999, recall 0.999, tp 99428.000, fp 98.000, fn 98.000, tn 98.000
# Epoch 360 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 361 :: learning rate 0.0001
# Epoch 361 :: Train loss 0.002, dice_lesion 0.758, dice_nonlesion 1.000, precision 0.999, recall 0.999, tp 99847.000, fp 50.000, fn 105.000, tn 105.000
# Epoch 361 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 362 :: learning rate 0.0001
# Epoch 362 :: Train loss 0.002, dice_lesion 0.793, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 121620.000, fp 6.000, fn 174.000, tn 174.000
# Epoch 362 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 363 :: learning rate 0.0001
# Epoch 363 :: Train loss 0.002, dice_lesion 0.724, dice_nonlesion 1.000, precision 1.000, recall 0.998, tp 114267.000, fp 14.000, fn 172.000, tn 172.000
# Epoch 363 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 364 :: learning rate 0.0001
# Epoch 364 :: Train loss 0.002, dice_lesion 0.827, dice_nonlesion 1.000, precision 0.999, recall 0.998, tp 107870.000, fp 138.000, fn 171.000, tn 171.000
# Epoch 364 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 365 :: learning rate 0.0001
# Epoch 365 :: Train loss 0.002, dice_lesion 0.723, dice_nonlesion 1.000, precision 0.999, recall 0.999, tp 97972.000, fp 143.000, fn 102.000, tn 102.000
# Epoch 365 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 366 :: learning rate 0.0001
# Epoch 366 :: Train loss 0.002, dice_lesion 0.793, dice_nonlesion 1.000, precision 0.999, recall 0.999, tp 102208.000, fp 106.000, fn 108.000, tn 108.000
# Epoch 366 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 367 :: learning rate 0.0001
# Epoch 367 :: Train loss 0.002, dice_lesion 0.758, dice_nonlesion 1.000, precision 1.000, recall 0.998, tp 109274.000, fp 0.000, fn 178.000, tn 178.000
# Epoch 367 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 368 :: learning rate 0.0001
# Epoch 368 :: Train loss 0.002, dice_lesion 0.758, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 88640.000, fp 39.000, fn 98.000, tn 98.000
# Epoch 368 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 369 :: learning rate 0.0001
# Epoch 369 :: Train loss 0.002, dice_lesion 0.689, dice_nonlesion 1.000, precision 0.999, recall 0.999, tp 96294.000, fp 99.000, fn 107.000, tn 107.000
# Epoch 369 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 370 :: learning rate 0.0001
# Epoch 370 :: Train loss 0.002, dice_lesion 0.758, dice_nonlesion 1.000, precision 1.000, recall 0.998, tp 105443.000, fp 0.000, fn 169.000, tn 169.000
# Epoch 370 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 371 :: learning rate 0.0001
# Epoch 371 :: Train loss 0.002, dice_lesion 0.689, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 107366.000, fp 3.000, fn 105.000, tn 105.000
# Epoch 371 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 372 :: learning rate 0.0001
# Epoch 372 :: Train loss 0.002, dice_lesion 0.689, dice_nonlesion 1.000, precision 0.999, recall 0.998, tp 113722.000, fp 134.000, fn 174.000, tn 174.000
# Epoch 372 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 373 :: learning rate 0.0001
# Epoch 373 :: Train loss 0.002, dice_lesion 0.724, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 101074.000, fp 7.000, fn 109.000, tn 109.000
# Epoch 373 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 374 :: learning rate 0.0001
# Epoch 374 :: Train loss 0.002, dice_lesion 0.689, dice_nonlesion 1.000, precision 0.999, recall 0.998, tp 112627.000, fp 103.000, fn 170.000, tn 170.000
# Epoch 374 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 375 :: learning rate 0.0001
# Epoch 375 :: Train loss 0.002, dice_lesion 0.586, dice_nonlesion 1.000, precision 0.998, recall 0.999, tp 81148.000, fp 135.000, fn 94.000, tn 94.000
# Epoch 375 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 376 :: learning rate 0.0001
# Epoch 376 :: Train loss 0.002, dice_lesion 0.724, dice_nonlesion 1.000, precision 1.000, recall 0.998, tp 109500.000, fp 37.000, fn 175.000, tn 175.000
# Epoch 376 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 377 :: learning rate 0.0001
# Epoch 377 :: Train loss 0.002, dice_lesion 0.690, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 107133.000, fp 0.000, fn 104.000, tn 104.000
# Epoch 377 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 378 :: learning rate 0.0001
# Epoch 378 :: Train loss 0.001, dice_lesion 0.793, dice_nonlesion 1.000, precision 0.999, recall 0.999, tp 97923.000, fp 97.000, fn 103.000, tn 103.000
# Epoch 378 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 379 :: learning rate 0.0001
# Epoch 379 :: Train loss 0.001, dice_lesion 0.827, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 111009.000, fp 43.000, fn 111.000, tn 111.000
# Epoch 379 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 380 :: learning rate 0.0001
# Epoch 380 :: Train loss 0.001, dice_lesion 0.721, dice_nonlesion 1.000, precision 0.999, recall 0.998, tp 92258.000, fp 103.000, fn 166.000, tn 166.000
# Epoch 380 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 381 :: learning rate 0.0001
# Epoch 381 :: Train loss 0.001, dice_lesion 0.690, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 91036.000, fp 6.000, fn 95.000, tn 95.000
# Epoch 381 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 382 :: learning rate 0.0001
# Epoch 382 :: Train loss 0.001, dice_lesion 0.689, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 100385.000, fp 2.000, fn 98.000, tn 98.000
# Epoch 382 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 383 :: learning rate 0.0001
# Epoch 383 :: Train loss 0.001, dice_lesion 0.827, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 102468.000, fp 37.000, fn 107.000, tn 107.000
# Epoch 383 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 384 :: learning rate 0.0001
# Epoch 384 :: Train loss 0.001, dice_lesion 0.758, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 123819.000, fp 2.000, fn 185.000, tn 185.000
# Epoch 384 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 385 :: learning rate 0.0001
# Epoch 385 :: Train loss 0.001, dice_lesion 0.724, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 101136.000, fp 0.000, fn 103.000, tn 103.000
# Epoch 385 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 386 :: learning rate 0.0001
# Epoch 386 :: Train loss 0.001, dice_lesion 0.790, dice_nonlesion 1.000, precision 0.999, recall 0.998, tp 101700.000, fp 121.000, fn 174.000, tn 174.000
# Epoch 386 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 387 :: learning rate 0.0001
# Epoch 387 :: Train loss 0.001, dice_lesion 0.827, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 99195.000, fp 26.000, fn 102.000, tn 102.000
# Epoch 387 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 388 :: learning rate 0.0001
# Epoch 388 :: Train loss 0.001, dice_lesion 0.757, dice_nonlesion 1.000, precision 0.999, recall 0.998, tp 109503.000, fp 124.000, fn 170.000, tn 170.000
# Epoch 388 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 389 :: learning rate 0.0001
# Epoch 389 :: Train loss 0.001, dice_lesion 0.724, dice_nonlesion 1.000, precision 0.999, recall 0.999, tp 99827.000, fp 101.000, fn 106.000, tn 106.000
# Epoch 389 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 390 :: learning rate 0.0001
# Epoch 390 :: Train loss 0.001, dice_lesion 0.758, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 102149.000, fp 24.000, fn 110.000, tn 110.000
# Epoch 390 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 391 :: learning rate 0.0001
# Epoch 391 :: Train loss 0.001, dice_lesion 0.724, dice_nonlesion 1.000, precision 1.000, recall 0.998, tp 101196.000, fp 0.000, fn 169.000, tn 169.000
# Epoch 391 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 392 :: learning rate 0.0001
# Epoch 392 :: Train loss 0.001, dice_lesion 0.689, dice_nonlesion 1.000, precision 0.999, recall 0.999, tp 77870.000, fp 115.000, fn 94.000, tn 94.000
# Epoch 392 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 393 :: learning rate 0.0001
# Epoch 393 :: Train loss 0.001, dice_lesion 0.689, dice_nonlesion 1.000, precision 0.999, recall 0.999, tp 104095.000, fp 113.000, fn 106.000, tn 106.000
# Epoch 393 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 394 :: learning rate 0.0001
# Epoch 394 :: Train loss 0.001, dice_lesion 0.758, dice_nonlesion 1.000, precision 1.000, recall 0.998, tp 113232.000, fp 20.000, fn 179.000, tn 179.000
# Epoch 394 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 395 :: learning rate 0.0001
# Epoch 395 :: Train loss 0.001, dice_lesion 0.655, dice_nonlesion 1.000, precision 0.999, recall 0.998, tp 101018.000, fp 108.000, fn 170.000, tn 170.000
# Epoch 395 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 396 :: learning rate 0.0001
# Epoch 396 :: Train loss 0.001, dice_lesion 0.653, dice_nonlesion 1.000, precision 0.999, recall 0.998, tp 102081.000, fp 98.000, fn 175.000, tn 175.000
# Epoch 396 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 397 :: learning rate 0.0001
# Epoch 397 :: Train loss 0.001, dice_lesion 0.724, dice_nonlesion 1.000, precision 0.999, recall 0.999, tp 120663.000, fp 96.000, fn 179.000, tn 179.000
# Epoch 397 :: Val   loss 0.002, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 398 :: learning rate 0.0001
# Epoch 398 :: Train loss 0.001, dice_lesion 0.724, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 97987.000, fp 12.000, fn 101.000, tn 101.000
# Epoch 398 :: Val   loss 0.001, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best
# Epoch 399 :: learning rate 0.0001
# Epoch 399 :: Train loss 0.001, dice_lesion 0.689, dice_nonlesion 1.000, precision 1.000, recall 0.999, tp 104276.000, fp 2.000, fn 111.000, tn 111.000
# Epoch 399 :: Val   loss 0.001, dice_lesion 0.500, dice_nonlesion 1.000, precision 1.000, recall 1.000, tp 697.000, fp 0.000, fn 0.000, tn 0.000
# saved_new_best

# %%
for p in exp.model.parameters():
    print(p)
# Out:
# Parameter containing:
# tensor([[-0.1594],
#         [-0.0392]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 0.3608, -0.4987], device='cuda:0', requires_grad=True)

# %%
idxs = trainer.val_data_loader.dataset.lesional_idxs

lesions = list(trainer.val_data_loader.dataset[idxs])

print(lesions[0].x[lesions[0].y > 0].mean(axis=0))
print(lesions[0].x[lesions[0].y == 0].mean(axis=0))
# Out:
# tensor([10.9818, 11.1576])
# tensor([0.0000, 0.4085])

# %%
idxs = trainer.train_data_loader.dataset.lesional_idxs

lesions = list(trainer.train_data_loader.dataset[idxs])

print(lesions[0].x[lesions[0].y > 0].mean(axis=0))
print(lesions[0].x[lesions[0].y == 0].mean(axis=0))
# Out:
# tensor([10.9865, 10.2297])
# tensor([0.0000, 0.2891])

# %%
data_true = lesions[0].y
sum(data_true)
# Out:
# tensor(650)

# %%
data_pred = exp.model(lesions[0].x.to(exp.model.device))[0]
data_pred = np.argmax(data_pred.cpu().detach(), axis=1)

# %%
sum(data_pred)
# Out:
# tensor(733)

# %%
sum(~(data_true == data_pred))
# Out:
# tensor(83)

# %%
lesions[0].x
# Out:
# tensor([[-0.0469, -0.9361],
#         [-0.0469,  2.6119],
#         [-0.0469, -0.1069],
#         ...,
#         [-0.0469, -0.2335],
#         [-0.0469, -0.1417],
#         [-0.0469, -0.0278]])

# %%
lesions[1].x
# Out:
# tensor([[-0.0126, -1.1752],
#         [-0.0126, -1.1540],
#         [-0.0126, -0.2428],
#         ...,
#         [-0.0126,  0.8933],
#         [-0.0126,  0.9001],
#         [-0.0126,  1.0584]])

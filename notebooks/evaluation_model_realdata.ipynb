# %%
import meld_graph
import meld_graph.models
import meld_graph.experiment
import meld_graph.dataset
import meld_graph.data_preprocessing
import meld_graph.evaluation


import importlib
importlib.reload(meld_graph)
importlib.reload(meld_graph.models)
importlib.reload(meld_graph.dataset)
importlib.reload(meld_graph.experiment)
importlib.reload(meld_graph.data_preprocessing)
importlib.reload(meld_graph.evaluation)

import logging
import os
import json

from meld_graph.dataset import GraphDataset, Oversampler
from meld_classifier.meld_cohort import MeldCohort, MeldSubject
from meld_graph.training import Metrics
import numpy as np
from meld_graph.paths import EXPERIMENT_PATH

from meld_graph.evaluation import Evaluator
# Out:
# Setting MELD_DATA_PATH to /rds/project/kw350/rds-kw350-meld/meld_data/Data
# Setting BASE_PATH to /rds/project/kw350/rds-kw350-meld/meld_data/Data
# Setting EXPERIMENT_PATH to /rds/project/kw350/rds-kw350-meld/experiments/co-ripa1/
# Setting FS_SUBJECTS_PATH to
# Setting EXPERIMENT_PATH to /rds/project/kw350/rds-kw350-meld/experiments_graph/co-ripa1

# %% [markdown]
# ### Generate dataset

# %%
#initialise dataset

cohort= MeldCohort(hdf5_file_root='{site_code}_{group}_featurematrix_combat_6.hdf5', dataset='MELD_dataset_V6.csv')

# initialise subjects manually in list or get from a csv dataset
subject_ids, trainval_ids, test_ids  = cohort.read_subject_ids_from_dataset()

subjects = test_ids
subjects.remove('MELD_H10_3T_FCD_0008')
subjects.remove('MELD_H23_15T_FCD_0002')


features= ['.combat.on_lh.pial.K_filtered.sm20.mgh',
          '.combat.on_lh.thickness.sm10.mgh',
          '.combat.on_lh.w-g.pct.sm10.mgh',
          '.combat.on_lh.sulc.sm5.mgh',
          '.combat.on_lh.curv.sm5.mgh',
          '.combat.on_lh.gm_FLAIR_0.75.sm10.mgh',
          '.combat.on_lh.gm_FLAIR_0.5.sm10.mgh',
          '.combat.on_lh.gm_FLAIR_0.25.sm10.mgh',
          '.combat.on_lh.gm_FLAIR_0.sm10.mgh',
          '.combat.on_lh.wm_FLAIR_0.5.sm10.mgh',
          '.combat.on_lh.wm_FLAIR_1.sm10.mgh',
          '.inter_z.intra_z.combat.on_lh.pial.K_filtered.sm20.mgh',
          '.inter_z.intra_z.combat.on_lh.thickness.sm10.mgh',
          '.inter_z.intra_z.combat.on_lh.w-g.pct.sm10.mgh',
          '.inter_z.intra_z.combat.on_lh.sulc.sm5.mgh',
          '.inter_z.intra_z.combat.on_lh.curv.sm5.mgh',
          '.inter_z.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh',
          '.inter_z.intra_z.combat.on_lh.gm_FLAIR_0.5.sm10.mgh',
          '.inter_z.intra_z.combat.on_lh.gm_FLAIR_0.25.sm10.mgh',
          '.inter_z.intra_z.combat.on_lh.gm_FLAIR_0.sm10.mgh',
          '.inter_z.intra_z.combat.on_lh.wm_FLAIR_0.5.sm10.mgh',
          '.inter_z.intra_z.combat.on_lh.wm_FLAIR_1.sm10.mgh',
          '.inter_z.asym.intra_z.combat.on_lh.pial.K_filtered.sm20.mgh',
          '.inter_z.asym.intra_z.combat.on_lh.thickness.sm10.mgh',
          '.inter_z.asym.intra_z.combat.on_lh.w-g.pct.sm10.mgh',
          '.inter_z.asym.intra_z.combat.on_lh.sulc.sm5.mgh',
          '.inter_z.asym.intra_z.combat.on_lh.curv.sm5.mgh',
          '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh',
          '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.5.sm10.mgh',
          '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.25.sm10.mgh',
          '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.sm10.mgh',
          '.inter_z.asym.intra_z.combat.on_lh.wm_FLAIR_0.5.sm10.mgh',
          '.inter_z.asym.intra_z.combat.on_lh.wm_FLAIR_1.sm10.mgh',]

# initiate params
params = {                
          "features":features,
          "augment_data": {}, 
          "lesion_bias":0,
          "lobes": False,
          "synthetic_data": {
              'run_synthetic': False,
              # 'n_subs': 200,
              # 'use_controls': True,
              # 'radius': 0.5,
              # 'n_subtypes': 25,
              # 'jitter_factor': 2,
              # 'bias': 1,
              # 'proportion_features_abnormal': 0.2,
              # 'proportion_hemispheres_lesional': 0.9,
            },
          "number_of_folds": 10,
          "preprocessing_parameters": {
              "scaling": None, 
              "zscore": '../data/feature_means.json',
            },
          "combine_hemis": None,
          }

#load dataset
dataset = GraphDataset(subjects, cohort, params, mode='test')

# %%
len(dataset.subject_ids)
# Out:
# 471

# %% [markdown]
# ### Load models and predict

# %%
# initialise models you want to run
EXPERIMENT_PATH='/rds/project/kw350/rds-kw350-meld/experiments_graph/kw350'

model_base_paths = {
    # unet deepsupervision trained on big lesions (radius 2)
   'augment_finetune_small': '/rds/project/kw350/rds-kw350-meld/experiments_graph/kw350/22-10-24_synth/unet/augment_finetune_real/fold_00/',
    '3layer_augment_finetune_small': '/rds/project/kw350/rds-kw350-meld/experiments_graph/kw350/22-10-24_synth/3layers/finetune_real/fold_00/',
}

# %%
from pyexpat import model

for model_name in model_base_paths.keys(): 
    
    #load experiment already trained using checkpoint path
    model_base_path=model_base_paths[model_name]
    checkpoint_path=os.path.join(EXPERIMENT_PATH, model_base_path)
    exp = meld_graph.experiment.Experiment.from_folder(checkpoint_path)

    # Run the evaluation on the test data and save into directory provided
    save_dir=os.path.join(EXPERIMENT_PATH,f'22-10-25_real_evaluation/{model_name}')

    eva = Evaluator(experiment = exp,
                    checkpoint_path = checkpoint_path,
                    save_dir = save_dir ,
                    make_images = True,
                    dataset=dataset,
                    cohort=cohort,
                )

    # evaluate (predict , stats and plot) or just run individually each step
    # eva.evaluate()
    
    # # load data and predict
    eva.load_predict_data()
    # # calculate stats 
    eva.stat_subjects()
    #  # make images 
    # eva.plot_subjects_prediction()
# Out:
# Initialised Experiment 22-10-24_synth/unet/augment_finetune_real
# Creating model
# Loading model weights from checkpoint /rds/project/kw350/rds-kw350-meld/experiments_graph/kw350/22-10-24_synth/unet/augment_finetune_real/fold_00/best_model.pt
# loading data and predicting model
# saving prediction for MELD2_H7_3T_FCD_001
# saving prediction for MELD2_H7_3T_FCD_002
# saving prediction for MELD2_H7_3T_FCD_004
# saving prediction for MELD2_H7_3T_FCD_005
# saving prediction for MELD2_H7_3T_FCD_009
# saving prediction for MELD2_H7_3T_FCD_011
# saving prediction for MELD2_H7_3T_FCD_014
# saving prediction for MELD_H10_3T_C_0005
# saving prediction for MELD_H10_3T_C_0006
# saving prediction for MELD_H10_3T_C_0009
# saving prediction for MELD_H10_3T_C_0011
# saving prediction for MELD_H10_3T_C_0012
# saving prediction for MELD_H10_3T_C_0013
# saving prediction for MELD_H10_3T_C_0014
# saving prediction for MELD_H10_3T_C_0015
# saving prediction for MELD_H10_3T_C_0017
# saving prediction for MELD_H10_3T_C_0018
# saving prediction for MELD_H10_3T_C_0019
# saving prediction for MELD_H10_3T_C_0021
# saving prediction for MELD_H10_3T_C_0022
# saving prediction for MELD_H10_3T_C_0025
# saving prediction for MELD_H10_3T_C_0028
# saving prediction for MELD_H10_3T_C_0029
# saving prediction for MELD_H10_3T_C_0031
# saving prediction for MELD_H10_3T_FCD_0002
# saving prediction for MELD_H10_3T_FCD_0009
# saving prediction for MELD_H10_3T_FCD_0013
# saving prediction for MELD_H10_3T_FCD_0014
# saving prediction for MELD_H10_3T_FCD_0016
# saving prediction for MELD_H11_3T_FCD_0002
# saving prediction for MELD_H11_3T_FCD_0006
# saving prediction for MELD_H11_3T_FCD_0007
# saving prediction for MELD_H11_3T_FCD_0009
# saving prediction for MELD_H11_3T_FCD_0010
# saving prediction for MELD_H11_3T_FCD_0011
# saving prediction for MELD_H11_3T_FCD_0015
# saving prediction for MELD_H11_3T_FCD_0019
# saving prediction for MELD_H11_3T_FCD_0020
# saving prediction for MELD_H11_3T_FCD_0025
# saving prediction for MELD_H11_3T_FCD_0027
# saving prediction for MELD_H11_3T_FCD_0028
# saving prediction for MELD_H11_3T_FCD_0030
# saving prediction for MELD_H11_3T_FCD_0031
# saving prediction for MELD_H11_3T_FCD_0040
# saving prediction for MELD_H11_3T_FCD_0041
# saving prediction for MELD_H11_3T_FCD_0042
# saving prediction for MELD_H11_3T_FCD_0044
# saving prediction for MELD_H11_3T_FCD_0045
# saving prediction for MELD_H12_15T_FCD_0001
# saving prediction for MELD_H12_15T_FCD_0003
# saving prediction for MELD_H12_15T_FCD_0005
# saving prediction for MELD_H12_3T_C_0002
# saving prediction for MELD_H12_3T_C_0004
# saving prediction for MELD_H12_3T_C_0005
# saving prediction for MELD_H12_3T_C_0007
# saving prediction for MELD_H12_3T_C_0010
# saving prediction for MELD_H12_3T_C_0011
# saving prediction for MELD_H12_3T_C_0014
# saving prediction for MELD_H12_3T_C_0016
# saving prediction for MELD_H12_3T_C_0018
# saving prediction for MELD_H12_3T_C_0023
# saving prediction for MELD_H12_3T_C_0024
# saving prediction for MELD_H12_3T_C_0025
# saving prediction for MELD_H12_3T_C_0026
# saving prediction for MELD_H12_3T_C_0028
# saving prediction for MELD_H12_3T_C_0029
# saving prediction for MELD_H12_3T_C_0031
# saving prediction for MELD_H12_3T_C_0032
# saving prediction for MELD_H12_3T_C_0034
# saving prediction for MELD_H12_3T_C_0035
# saving prediction for MELD_H12_3T_C_0036
# saving prediction for MELD_H12_3T_C_0037
# saving prediction for MELD_H12_3T_C_0038
# saving prediction for MELD_H12_3T_C_0040
# saving prediction for MELD_H12_3T_C_0041
# saving prediction for MELD_H12_3T_C_0042
# saving prediction for MELD_H12_3T_C_0044
# saving prediction for MELD_H12_3T_C_0045
# saving prediction for MELD_H12_3T_C_0050
# saving prediction for MELD_H12_3T_C_0051
# saving prediction for MELD_H12_3T_C_0052
# saving prediction for MELD_H12_3T_FCD_0003
# saving prediction for MELD_H12_3T_FCD_0006
# saving prediction for MELD_H12_3T_FCD_0007
# saving prediction for MELD_H12_3T_FCD_0009
# saving prediction for MELD_H12_3T_FCD_0011
# saving prediction for MELD_H12_3T_FCD_0014
# saving prediction for MELD_H12_3T_FCD_0016
# saving prediction for MELD_H12_3T_FCD_0018
# saving prediction for MELD_H12_3T_FCD_0023
# saving prediction for MELD_H12_3T_FCD_0024
# saving prediction for MELD_H12_3T_FCD_0030
# saving prediction for MELD_H12_3T_FCD_0031
# saving prediction for MELD_H14_3T_C_0001
# saving prediction for MELD_H14_3T_C_0002
# saving prediction for MELD_H14_3T_C_0003
# saving prediction for MELD_H14_3T_C_0005
# saving prediction for MELD_H14_3T_C_0010
# saving prediction for MELD_H14_3T_C_0012
# saving prediction for MELD_H14_3T_C_0014
# saving prediction for MELD_H14_3T_C_0015
# saving prediction for MELD_H14_3T_C_0016
# saving prediction for MELD_H14_3T_C_0017
# saving prediction for MELD_H14_3T_C_0019
# saving prediction for MELD_H14_3T_C_0020
# saving prediction for MELD_H14_3T_C_0021
# saving prediction for MELD_H14_3T_C_0024
# saving prediction for MELD_H14_3T_C_0025
# saving prediction for MELD_H14_3T_FCD_0009
# saving prediction for MELD_H14_3T_FCD_0011
# saving prediction for MELD_H14_3T_FCD_0013
# saving prediction for MELD_H14_3T_FCD_0016
# saving prediction for MELD_H14_3T_FCD_0017
# saving prediction for MELD_H14_3T_FCD_0021
# saving prediction for MELD_H14_3T_FCD_0022
# saving prediction for MELD_H14_3T_FCD_0023
# saving prediction for MELD_H14_3T_FCD_0024
# saving prediction for MELD_H14_3T_FCD_0025
# saving prediction for MELD_H14_3T_FCD_0026
# saving prediction for MELD_H14_3T_FCD_0029
# saving prediction for MELD_H14_3T_FCD_0030
# saving prediction for MELD_H14_3T_FCD_0031
# saving prediction for MELD_H14_3T_FCD_0034
# saving prediction for MELD_H14_3T_FCD_0035
# saving prediction for MELD_H14_3T_FCD_0037
# saving prediction for MELD_H14_3T_FCD_0039
# saving prediction for MELD_H14_3T_FCD_0040
# saving prediction for MELD_H14_3T_FCD_0042
# saving prediction for MELD_H15_3T_C_0001
# saving prediction for MELD_H15_3T_C_0006
# saving prediction for MELD_H15_3T_C_0007
# saving prediction for MELD_H15_3T_C_0012
# saving prediction for MELD_H15_3T_C_0013
# saving prediction for MELD_H15_3T_C_0015
# saving prediction for MELD_H15_3T_C_0018
# saving prediction for MELD_H15_3T_C_0019
# saving prediction for MELD_H15_3T_C_0025
# saving prediction for MELD_H15_3T_C_0027
# saving prediction for MELD_H15_3T_C_0030
# saving prediction for MELD_H15_3T_C_0031
# saving prediction for MELD_H15_3T_C_0032
# saving prediction for MELD_H15_3T_C_0033
# saving prediction for MELD_H15_3T_FCD_0003
# saving prediction for MELD_H15_3T_FCD_0004
# saving prediction for MELD_H15_3T_FCD_0007
# saving prediction for MELD_H15_3T_FCD_0008
# saving prediction for MELD_H15_3T_FCD_0010
# saving prediction for MELD_H16_3T_FCD_001
# saving prediction for MELD_H16_3T_FCD_003
# saving prediction for MELD_H16_3T_FCD_004
# saving prediction for MELD_H16_3T_FCD_005
# saving prediction for MELD_H16_3T_FCD_008
# saving prediction for MELD_H16_3T_FCD_010
# saving prediction for MELD_H16_3T_FCD_013
# saving prediction for MELD_H16_3T_FCD_015
# saving prediction for MELD_H16_3T_FCD_016
# saving prediction for MELD_H16_3T_FCD_017
# saving prediction for MELD_H16_3T_FCD_022
# saving prediction for MELD_H16_3T_FCD_023
# saving prediction for MELD_H16_3T_FCD_026
# saving prediction for MELD_H16_3T_FCD_045
# saving prediction for MELD_H16_3T_FCD_048
# saving prediction for MELD_H17_15T_FCD_0011
# saving prediction for MELD_H17_15T_FCD_0017
# saving prediction for MELD_H17_15T_FCD_0102
# saving prediction for MELD_H17_15T_FCD_0104
# saving prediction for MELD_H17_15T_FCD_0139
# saving prediction for MELD_H17_3T_FCD_0001
# saving prediction for MELD_H17_3T_FCD_0014
# saving prediction for MELD_H17_3T_FCD_0018
# saving prediction for MELD_H17_3T_FCD_0022
# saving prediction for MELD_H17_3T_FCD_0039
# saving prediction for MELD_H17_3T_FCD_0043
# saving prediction for MELD_H17_3T_FCD_0044
# saving prediction for MELD_H17_3T_FCD_0053
# saving prediction for MELD_H17_3T_FCD_0054
# saving prediction for MELD_H17_3T_FCD_0057
# saving prediction for MELD_H17_3T_FCD_0061
# saving prediction for MELD_H17_3T_FCD_0067
# saving prediction for MELD_H17_3T_FCD_0070
# saving prediction for MELD_H17_3T_FCD_0076
# saving prediction for MELD_H17_3T_FCD_0079
# saving prediction for MELD_H17_3T_FCD_0084
# saving prediction for MELD_H17_3T_FCD_0086
# saving prediction for MELD_H17_3T_FCD_0090
# saving prediction for MELD_H17_3T_FCD_0091
# saving prediction for MELD_H17_3T_FCD_0094
# saving prediction for MELD_H17_3T_FCD_0098
# saving prediction for MELD_H17_3T_FCD_0112
# saving prediction for MELD_H17_3T_FCD_0116
# saving prediction for MELD_H17_3T_FCD_0120
# saving prediction for MELD_H17_3T_FCD_0127
# saving prediction for MELD_H17_3T_FCD_0135
# saving prediction for MELD_H17_3T_FCD_0143
# saving prediction for MELD_H18_3T_FCD_0001
# saving prediction for MELD_H18_3T_FCD_0006
# saving prediction for MELD_H18_3T_FCD_0008
# saving prediction for MELD_H18_3T_FCD_0009
# saving prediction for MELD_H18_3T_FCD_0101
# saving prediction for MELD_H18_3T_FCD_0109
# saving prediction for MELD_H18_3T_FCD_0115
# saving prediction for MELD_H18_3T_FCD_0124
# saving prediction for MELD_H19_3T_C_008
# saving prediction for MELD_H19_3T_C_014
# saving prediction for MELD_H19_3T_C_017
# saving prediction for MELD_H19_3T_C_018
# saving prediction for MELD_H19_3T_C_020
# saving prediction for MELD_H19_3T_C_024
# saving prediction for MELD_H19_3T_C_025
# saving prediction for MELD_H19_3T_C_026
# saving prediction for MELD_H19_3T_C_029
# saving prediction for MELD_H19_3T_C_031
# saving prediction for MELD_H21_15T_FCD_0036
# saving prediction for MELD_H21_15T_FCD_0038
# saving prediction for MELD_H21_15T_FCD_0040
# saving prediction for MELD_H21_15T_FCD_0043
# saving prediction for MELD_H21_15T_FCD_0047
# saving prediction for MELD_H21_15T_FCD_0049
# saving prediction for MELD_H21_15T_FCD_0050
# saving prediction for MELD_H21_15T_FCD_0051
# saving prediction for MELD_H21_15T_FCD_0052
# saving prediction for MELD_H21_3T_FCD_0007
# saving prediction for MELD_H21_3T_FCD_0008
# saving prediction for MELD_H21_3T_FCD_0009
# saving prediction for MELD_H21_3T_FCD_0013
# saving prediction for MELD_H21_3T_FCD_0016
# saving prediction for MELD_H21_3T_FCD_0017
# saving prediction for MELD_H21_3T_FCD_0018
# saving prediction for MELD_H21_3T_FCD_0030
# saving prediction for MELD_H21_3T_FCD_0033
# saving prediction for MELD_H21_3T_FCD_0034
# saving prediction for MELD_H21_3T_FCD_0035
# saving prediction for MELD_H21_3T_FCD_0046
# saving prediction for MELD_H21_3T_FCD_0048
# saving prediction for MELD_H23_15T_FCD_0003
# saving prediction for MELD_H23_15T_FCD_0004
# saving prediction for MELD_H23_15T_FCD_0005
# saving prediction for MELD_H23_15T_FCD_0011
# saving prediction for MELD_H23_15T_FCD_0013
# saving prediction for MELD_H23_15T_FCD_0015
# saving prediction for MELD_H23_15T_FCD_0020
# saving prediction for MELD_H23_15T_FCD_0021
# saving prediction for MELD_H23_15T_FCD_0022
# saving prediction for MELD_H23_15T_FCD_0023
# saving prediction for MELD_H23_15T_FCD_0025
# saving prediction for MELD_H23_15T_FCD_0027
# saving prediction for MELD_H23_15T_FCD_0030
# saving prediction for MELD_H23_15T_FCD_0031
# saving prediction for MELD_H23_15T_FCD_0032
# saving prediction for MELD_H24_3T_FCD_0003
# saving prediction for MELD_H24_3T_FCD_0005
# saving prediction for MELD_H24_3T_FCD_0006
# saving prediction for MELD_H24_3T_FCD_0007
# saving prediction for MELD_H24_3T_FCD_0011
# saving prediction for MELD_H24_3T_FCD_0012
# saving prediction for MELD_H24_3T_FCD_0013
# saving prediction for MELD_H24_3T_FCD_0015
# saving prediction for MELD_H24_3T_FCD_0025
# saving prediction for MELD_H24_3T_FCD_0026
# saving prediction for MELD_H24_3T_FCD_0029
# saving prediction for MELD_H24_3T_FCD_0030
# saving prediction for MELD_H24_3T_FCD_0036
# saving prediction for MELD_H24_3T_FCD_0037
# saving prediction for MELD_H24_3T_FCD_0040
# saving prediction for MELD_H24_3T_FCD_0041
# saving prediction for MELD_H26_15T_FCD_0001
# saving prediction for MELD_H26_15T_FCD_0005
# saving prediction for MELD_H26_15T_FCD_0009
# saving prediction for MELD_H26_15T_FCD_0010
# saving prediction for MELD_H26_3T_FCD_0002
# saving prediction for MELD_H26_3T_FCD_0004
# saving prediction for MELD_H26_3T_FCD_0007
# saving prediction for MELD_H2_15T_C_0001
# saving prediction for MELD_H2_15T_FCD_0001
# saving prediction for MELD_H2_15T_FCD_0003
# saving prediction for MELD_H2_15T_FCD_0005
# saving prediction for MELD_H2_15T_FCD_0007
# saving prediction for MELD_H2_15T_FCD_0008
# saving prediction for MELD_H2_15T_FCD_0009
# saving prediction for MELD_H2_15T_FCD_0014
# saving prediction for MELD_H2_15T_FCD_0015
# saving prediction for MELD_H2_15T_FCD_0016
# saving prediction for MELD_H2_15T_FCD_0020
# saving prediction for MELD_H2_15T_FCD_0023
# saving prediction for MELD_H2_15T_FCD_0028
# saving prediction for MELD_H2_15T_FCD_0029
# saving prediction for MELD_H2_15T_FCD_0030
# saving prediction for MELD_H2_3T_C_0001
# saving prediction for MELD_H2_3T_C_0003
# saving prediction for MELD_H2_3T_C_0007
# saving prediction for MELD_H2_3T_C_0008
# saving prediction for MELD_H2_3T_C_0009
# saving prediction for MELD_H2_3T_C_0012
# saving prediction for MELD_H2_3T_C_0013
# saving prediction for MELD_H2_3T_C_0014
# saving prediction for MELD_H2_3T_C_0017
# saving prediction for MELD_H2_3T_C_0019
# saving prediction for MELD_H2_3T_C_0020
# saving prediction for MELD_H2_3T_C_0021
# saving prediction for MELD_H2_3T_C_0025
# saving prediction for MELD_H2_3T_C_0027
# saving prediction for MELD_H2_3T_C_0029
# saving prediction for MELD_H2_3T_C_0030
# saving prediction for MELD_H2_3T_C_0031
# saving prediction for MELD_H2_3T_FCD_0003
# saving prediction for MELD_H2_3T_FCD_0004
# saving prediction for MELD_H2_3T_FCD_0005
# saving prediction for MELD_H2_3T_FCD_0006
# saving prediction for MELD_H2_3T_FCD_0008
# saving prediction for MELD_H2_3T_FCD_0014
# saving prediction for MELD_H2_3T_FCD_0016
# saving prediction for MELD_H2_3T_FCD_0017
# saving prediction for MELD_H2_3T_FCD_0018
# saving prediction for MELD_H3_3T_C_0003
# saving prediction for MELD_H3_3T_C_0004
# saving prediction for MELD_H3_3T_C_0010
# saving prediction for MELD_H3_3T_C_0011
# saving prediction for MELD_H3_3T_C_0012
# saving prediction for MELD_H3_3T_C_0013
# saving prediction for MELD_H3_3T_C_0016
# saving prediction for MELD_H3_3T_C_0017
# saving prediction for MELD_H3_3T_C_0021
# saving prediction for MELD_H3_3T_C_0023
# saving prediction for MELD_H3_3T_C_0028
# saving prediction for MELD_H3_3T_C_0034
# saving prediction for MELD_H3_3T_C_0035
# saving prediction for MELD_H3_3T_C_0036
# saving prediction for MELD_H3_3T_C_0038
# saving prediction for MELD_H3_3T_C_0039
# saving prediction for MELD_H3_3T_C_0040
# saving prediction for MELD_H3_3T_C_0042
# saving prediction for MELD_H3_3T_C_0043
# saving prediction for MELD_H3_3T_C_0044
# saving prediction for MELD_H3_3T_C_0047
# saving prediction for MELD_H3_3T_C_0048
# saving prediction for MELD_H3_3T_C_0051
# saving prediction for MELD_H3_3T_C_0058
# saving prediction for MELD_H3_3T_C_0061
# saving prediction for MELD_H3_3T_C_0066
# saving prediction for MELD_H3_3T_C_0067
# saving prediction for MELD_H3_3T_C_0068
# saving prediction for MELD_H3_3T_C_0070
# saving prediction for MELD_H3_3T_C_0071
# saving prediction for MELD_H3_3T_C_0072
# saving prediction for MELD_H3_3T_C_0075
# saving prediction for MELD_H3_3T_C_0076
# saving prediction for MELD_H3_3T_C_0077
# saving prediction for MELD_H3_3T_C_0079
# saving prediction for MELD_H3_3T_C_0080
# saving prediction for MELD_H3_3T_C_0081
# saving prediction for MELD_H3_3T_C_0082
# saving prediction for MELD_H3_3T_C_0084
# saving prediction for MELD_H3_3T_C_0085
# saving prediction for MELD_H3_3T_C_0088
# saving prediction for MELD_H3_3T_C_0095
# saving prediction for MELD_H3_3T_C_0096
# saving prediction for MELD_H3_3T_C_0099
# saving prediction for MELD_H3_3T_FCD_0002
# saving prediction for MELD_H3_3T_FCD_0003
# saving prediction for MELD_H3_3T_FCD_0004
# saving prediction for MELD_H3_3T_FCD_0005
# saving prediction for MELD_H3_3T_FCD_0007
# saving prediction for MELD_H3_3T_FCD_0008
# saving prediction for MELD_H3_3T_FCD_0009
# saving prediction for MELD_H3_3T_FCD_0010
# saving prediction for MELD_H3_3T_FCD_0012
# saving prediction for MELD_H3_3T_FCD_0014
# saving prediction for MELD_H3_3T_FCD_0015
# saving prediction for MELD_H3_3T_FCD_0016
# saving prediction for MELD_H3_3T_FCD_0018
# saving prediction for MELD_H3_3T_FCD_0020
# saving prediction for MELD_H3_3T_FCD_0022
# saving prediction for MELD_H3_3T_FCD_0023
# saving prediction for MELD_H4_15T_C_0001
# saving prediction for MELD_H4_15T_C_0002
# saving prediction for MELD_H4_15T_C_0007
# saving prediction for MELD_H4_15T_C_0011
# saving prediction for MELD_H4_15T_C_0012
# saving prediction for MELD_H4_15T_C_0014
# saving prediction for MELD_H4_15T_C_0018
# saving prediction for MELD_H4_15T_C_0020
# saving prediction for MELD_H4_15T_C_0022
# saving prediction for MELD_H4_15T_C_0024
# saving prediction for MELD_H4_15T_C_0025
# saving prediction for MELD_H4_15T_C_0026
# saving prediction for MELD_H4_15T_C_0029
# saving prediction for MELD_H4_15T_C_0030
# saving prediction for MELD_H4_15T_FCD_0002
# saving prediction for MELD_H4_15T_FCD_0003
# saving prediction for MELD_H4_15T_FCD_0009
# saving prediction for MELD_H4_15T_FCD_0016
# saving prediction for MELD_H4_15T_FCD_0017
# saving prediction for MELD_H4_15T_FCD_0018
# saving prediction for MELD_H4_15T_FCD_0019
# saving prediction for MELD_H4_15T_FCD_0020
# saving prediction for MELD_H4_15T_FCD_0021
# saving prediction for MELD_H4_3T_C_0001
# saving prediction for MELD_H4_3T_C_0007
# saving prediction for MELD_H4_3T_C_0009
# saving prediction for MELD_H4_3T_C_0010
# saving prediction for MELD_H4_3T_C_0012
# saving prediction for MELD_H4_3T_C_0013
# saving prediction for MELD_H4_3T_C_0015
# saving prediction for MELD_H4_3T_C_0016
# saving prediction for MELD_H4_3T_FCD_0002
# saving prediction for MELD_H4_3T_FCD_0005
# saving prediction for MELD_H4_3T_FCD_0007
# saving prediction for MELD_H4_3T_FCD_0009
# saving prediction for MELD_H4_3T_FCD_0010
# saving prediction for MELD_H4_3T_FCD_0015
# saving prediction for MELD_H4_3T_FCD_0016
# saving prediction for MELD_H4_3T_FCD_0031
# saving prediction for MELD_H4_3T_FCD_0038
# saving prediction for MELD_H4_3T_FCD_0040
# saving prediction for MELD_H5_3T_C_0001
# saving prediction for MELD_H5_3T_C_0002
# saving prediction for MELD_H5_3T_C_0004
# saving prediction for MELD_H5_3T_C_0006
# saving prediction for MELD_H5_3T_C_0007
# saving prediction for MELD_H5_3T_C_0009
# saving prediction for MELD_H5_3T_C_0010
# saving prediction for MELD_H5_3T_C_0011
# saving prediction for MELD_H5_3T_C_0012
# saving prediction for MELD_H5_3T_C_0014
# saving prediction for MELD_H5_3T_C_0015
# saving prediction for MELD_H5_3T_C_0016
# saving prediction for MELD_H5_3T_C_0017
# saving prediction for MELD_H5_3T_C_0018
# saving prediction for MELD_H5_3T_C_0019
# saving prediction for MELD_H5_3T_C_0021
# saving prediction for MELD_H5_3T_C_0025
# saving prediction for MELD_H5_3T_C_0027
# saving prediction for MELD_H5_3T_C_0029
# saving prediction for MELD_H5_3T_FCD_0001
# saving prediction for MELD_H5_3T_FCD_0004
# saving prediction for MELD_H5_3T_FCD_0005
# saving prediction for MELD_H5_3T_FCD_0006
# saving prediction for MELD_H5_3T_FCD_0007
# saving prediction for MELD_H5_3T_FCD_0009
# saving prediction for MELD_H5_3T_FCD_0011
# saving prediction for MELD_H5_3T_FCD_0013
# saving prediction for MELD_H5_3T_FCD_0014
# saving prediction for MELD_H5_3T_FCD_0015
# saving prediction for MELD_H5_3T_FCD_0017
# saving prediction for MELD_H5_3T_FCD_0020
# saving prediction for MELD_H5_3T_FCD_0021
# saving prediction for MELD_H5_3T_FCD_0022
# saving prediction for MELD_H5_3T_FCD_0024
# saving prediction for MELD_H5_3T_FCD_0025
# saving prediction for MELD_H5_3T_FCD_0026
# saving prediction for MELD_H5_3T_FCD_0029
# saving prediction for MELD_H6_3T_FCD_0004
# saving prediction for MELD_H6_3T_FCD_0005
# saving prediction for MELD_H6_3T_FCD_0006
# saving prediction for MELD_H6_3T_FCD_0008
# saving prediction for MELD_H6_3T_FCD_0009
# saving prediction for MELD_H6_3T_FCD_0011
# saving prediction for MELD_H6_3T_FCD_0013
# saving prediction for MELD_H6_3T_FCD_0014
# saving prediction for MELD_H6_3T_FCD_0015
# saving prediction for MELD_H6_3T_FCD_0017
# saving prediction for MELD_H6_3T_FCD_0019
# saving prediction for MELD_H9_3T_C_0002
# saving prediction for MELD_H9_3T_C_0005
# saving prediction for MELD_H9_3T_C_0007
# saving prediction for MELD_H9_3T_C_0009
# saving prediction for MELD_H9_3T_FCD_0003
# saving prediction for MELD_H9_3T_FCD_0004
# saving prediction for MELD_H9_3T_FCD_0005
# saving prediction for MELD_H9_3T_FCD_0010
# saving prediction for MELD_H5_3T_FCD_0032
# Initialised Experiment 22-10-24_synth/3layers/finetune_real
# Creating model
# Loading model weights from checkpoint /rds/project/kw350/rds-kw350-meld/experiments_graph/kw350/22-10-24_synth/3layers/finetune_real/fold_00/best_model.pt
# loading data and predicting model
# saving prediction for MELD2_H7_3T_FCD_001
# saving prediction for MELD2_H7_3T_FCD_002
# saving prediction for MELD2_H7_3T_FCD_004
# saving prediction for MELD2_H7_3T_FCD_005
# saving prediction for MELD2_H7_3T_FCD_009
# saving prediction for MELD2_H7_3T_FCD_011
# saving prediction for MELD2_H7_3T_FCD_014
# saving prediction for MELD_H10_3T_C_0005
# saving prediction for MELD_H10_3T_C_0006
# saving prediction for MELD_H10_3T_C_0009
# saving prediction for MELD_H10_3T_C_0011
# saving prediction for MELD_H10_3T_C_0012
# saving prediction for MELD_H10_3T_C_0013
# saving prediction for MELD_H10_3T_C_0014
# saving prediction for MELD_H10_3T_C_0015
# saving prediction for MELD_H10_3T_C_0017
# saving prediction for MELD_H10_3T_C_0018
# saving prediction for MELD_H10_3T_C_0019
# saving prediction for MELD_H10_3T_C_0021
# saving prediction for MELD_H10_3T_C_0022
# saving prediction for MELD_H10_3T_C_0025
# saving prediction for MELD_H10_3T_C_0028
# saving prediction for MELD_H10_3T_C_0029
# saving prediction for MELD_H10_3T_C_0031
# saving prediction for MELD_H10_3T_FCD_0002
# saving prediction for MELD_H10_3T_FCD_0009
# saving prediction for MELD_H10_3T_FCD_0013
# saving prediction for MELD_H10_3T_FCD_0014
# saving prediction for MELD_H10_3T_FCD_0016
# saving prediction for MELD_H11_3T_FCD_0002
# saving prediction for MELD_H11_3T_FCD_0006
# saving prediction for MELD_H11_3T_FCD_0007
# saving prediction for MELD_H11_3T_FCD_0009
# saving prediction for MELD_H11_3T_FCD_0010
# saving prediction for MELD_H11_3T_FCD_0011
# saving prediction for MELD_H11_3T_FCD_0015
# saving prediction for MELD_H11_3T_FCD_0019
# saving prediction for MELD_H11_3T_FCD_0020
# saving prediction for MELD_H11_3T_FCD_0025
# saving prediction for MELD_H11_3T_FCD_0027
# saving prediction for MELD_H11_3T_FCD_0028
# saving prediction for MELD_H11_3T_FCD_0030
# saving prediction for MELD_H11_3T_FCD_0031
# saving prediction for MELD_H11_3T_FCD_0040
# saving prediction for MELD_H11_3T_FCD_0041
# saving prediction for MELD_H11_3T_FCD_0042
# saving prediction for MELD_H11_3T_FCD_0044
# saving prediction for MELD_H11_3T_FCD_0045
# saving prediction for MELD_H12_15T_FCD_0001
# saving prediction for MELD_H12_15T_FCD_0003
# saving prediction for MELD_H12_15T_FCD_0005
# saving prediction for MELD_H12_3T_C_0002
# saving prediction for MELD_H12_3T_C_0004
# saving prediction for MELD_H12_3T_C_0005
# saving prediction for MELD_H12_3T_C_0007
# saving prediction for MELD_H12_3T_C_0010
# saving prediction for MELD_H12_3T_C_0011
# saving prediction for MELD_H12_3T_C_0014
# saving prediction for MELD_H12_3T_C_0016
# saving prediction for MELD_H12_3T_C_0018
# saving prediction for MELD_H12_3T_C_0023
# saving prediction for MELD_H12_3T_C_0024
# saving prediction for MELD_H12_3T_C_0025
# saving prediction for MELD_H12_3T_C_0026
# saving prediction for MELD_H12_3T_C_0028
# saving prediction for MELD_H12_3T_C_0029
# saving prediction for MELD_H12_3T_C_0031
# saving prediction for MELD_H12_3T_C_0032
# saving prediction for MELD_H12_3T_C_0034
# saving prediction for MELD_H12_3T_C_0035
# saving prediction for MELD_H12_3T_C_0036
# saving prediction for MELD_H12_3T_C_0037
# saving prediction for MELD_H12_3T_C_0038
# saving prediction for MELD_H12_3T_C_0040
# saving prediction for MELD_H12_3T_C_0041
# saving prediction for MELD_H12_3T_C_0042
# saving prediction for MELD_H12_3T_C_0044
# saving prediction for MELD_H12_3T_C_0045
# saving prediction for MELD_H12_3T_C_0050
# saving prediction for MELD_H12_3T_C_0051
# saving prediction for MELD_H12_3T_C_0052
# saving prediction for MELD_H12_3T_FCD_0003
# saving prediction for MELD_H12_3T_FCD_0006
# saving prediction for MELD_H12_3T_FCD_0007
# saving prediction for MELD_H12_3T_FCD_0009
# saving prediction for MELD_H12_3T_FCD_0011
# saving prediction for MELD_H12_3T_FCD_0014
# saving prediction for MELD_H12_3T_FCD_0016
# saving prediction for MELD_H12_3T_FCD_0018
# saving prediction for MELD_H12_3T_FCD_0023
# saving prediction for MELD_H12_3T_FCD_0024
# saving prediction for MELD_H12_3T_FCD_0030
# saving prediction for MELD_H12_3T_FCD_0031
# saving prediction for MELD_H14_3T_C_0001
# saving prediction for MELD_H14_3T_C_0002
# saving prediction for MELD_H14_3T_C_0003
# saving prediction for MELD_H14_3T_C_0005
# saving prediction for MELD_H14_3T_C_0010
# saving prediction for MELD_H14_3T_C_0012
# saving prediction for MELD_H14_3T_C_0014
# saving prediction for MELD_H14_3T_C_0015
# saving prediction for MELD_H14_3T_C_0016
# saving prediction for MELD_H14_3T_C_0017
# saving prediction for MELD_H14_3T_C_0019
# saving prediction for MELD_H14_3T_C_0020
# saving prediction for MELD_H14_3T_C_0021
# saving prediction for MELD_H14_3T_C_0024
# saving prediction for MELD_H14_3T_C_0025
# saving prediction for MELD_H14_3T_FCD_0009
# saving prediction for MELD_H14_3T_FCD_0011
# saving prediction for MELD_H14_3T_FCD_0013
# saving prediction for MELD_H14_3T_FCD_0016
# saving prediction for MELD_H14_3T_FCD_0017
# saving prediction for MELD_H14_3T_FCD_0021
# saving prediction for MELD_H14_3T_FCD_0022
# saving prediction for MELD_H14_3T_FCD_0023
# saving prediction for MELD_H14_3T_FCD_0024
# saving prediction for MELD_H14_3T_FCD_0025
# saving prediction for MELD_H14_3T_FCD_0026
# saving prediction for MELD_H14_3T_FCD_0029
# saving prediction for MELD_H14_3T_FCD_0030
# saving prediction for MELD_H14_3T_FCD_0031
# saving prediction for MELD_H14_3T_FCD_0034
# saving prediction for MELD_H14_3T_FCD_0035
# saving prediction for MELD_H14_3T_FCD_0037
# saving prediction for MELD_H14_3T_FCD_0039
# saving prediction for MELD_H14_3T_FCD_0040
# saving prediction for MELD_H14_3T_FCD_0042
# saving prediction for MELD_H15_3T_C_0001
# saving prediction for MELD_H15_3T_C_0006
# saving prediction for MELD_H15_3T_C_0007
# saving prediction for MELD_H15_3T_C_0012
# saving prediction for MELD_H15_3T_C_0013
# saving prediction for MELD_H15_3T_C_0015
# saving prediction for MELD_H15_3T_C_0018
# saving prediction for MELD_H15_3T_C_0019
# saving prediction for MELD_H15_3T_C_0025
# saving prediction for MELD_H15_3T_C_0027
# saving prediction for MELD_H15_3T_C_0030
# saving prediction for MELD_H15_3T_C_0031
# saving prediction for MELD_H15_3T_C_0032
# saving prediction for MELD_H15_3T_C_0033
# saving prediction for MELD_H15_3T_FCD_0003
# saving prediction for MELD_H15_3T_FCD_0004
# saving prediction for MELD_H15_3T_FCD_0007
# saving prediction for MELD_H15_3T_FCD_0008
# saving prediction for MELD_H15_3T_FCD_0010
# saving prediction for MELD_H16_3T_FCD_001
# saving prediction for MELD_H16_3T_FCD_003
# saving prediction for MELD_H16_3T_FCD_004
# saving prediction for MELD_H16_3T_FCD_005
# saving prediction for MELD_H16_3T_FCD_008
# saving prediction for MELD_H16_3T_FCD_010
# saving prediction for MELD_H16_3T_FCD_013
# saving prediction for MELD_H16_3T_FCD_015
# saving prediction for MELD_H16_3T_FCD_016
# saving prediction for MELD_H16_3T_FCD_017
# saving prediction for MELD_H16_3T_FCD_022
# saving prediction for MELD_H16_3T_FCD_023
# saving prediction for MELD_H16_3T_FCD_026
# saving prediction for MELD_H16_3T_FCD_045
# saving prediction for MELD_H16_3T_FCD_048
# saving prediction for MELD_H17_15T_FCD_0011
# saving prediction for MELD_H17_15T_FCD_0017
# saving prediction for MELD_H17_15T_FCD_0102
# saving prediction for MELD_H17_15T_FCD_0104
# saving prediction for MELD_H17_15T_FCD_0139
# saving prediction for MELD_H17_3T_FCD_0001
# saving prediction for MELD_H17_3T_FCD_0014
# saving prediction for MELD_H17_3T_FCD_0018
# saving prediction for MELD_H17_3T_FCD_0022
# saving prediction for MELD_H17_3T_FCD_0039
# saving prediction for MELD_H17_3T_FCD_0043
# saving prediction for MELD_H17_3T_FCD_0044
# saving prediction for MELD_H17_3T_FCD_0053
# saving prediction for MELD_H17_3T_FCD_0054
# saving prediction for MELD_H17_3T_FCD_0057
# saving prediction for MELD_H17_3T_FCD_0061
# saving prediction for MELD_H17_3T_FCD_0067
# saving prediction for MELD_H17_3T_FCD_0070
# saving prediction for MELD_H17_3T_FCD_0076
# saving prediction for MELD_H17_3T_FCD_0079
# saving prediction for MELD_H17_3T_FCD_0084
# saving prediction for MELD_H17_3T_FCD_0086
# saving prediction for MELD_H17_3T_FCD_0090
# saving prediction for MELD_H17_3T_FCD_0091
# saving prediction for MELD_H17_3T_FCD_0094
# saving prediction for MELD_H17_3T_FCD_0098
# saving prediction for MELD_H17_3T_FCD_0112
# saving prediction for MELD_H17_3T_FCD_0116
# saving prediction for MELD_H17_3T_FCD_0120
# saving prediction for MELD_H17_3T_FCD_0127
# saving prediction for MELD_H17_3T_FCD_0135
# saving prediction for MELD_H17_3T_FCD_0143
# saving prediction for MELD_H18_3T_FCD_0001
# saving prediction for MELD_H18_3T_FCD_0006
# saving prediction for MELD_H18_3T_FCD_0008
# saving prediction for MELD_H18_3T_FCD_0009
# saving prediction for MELD_H18_3T_FCD_0101
# saving prediction for MELD_H18_3T_FCD_0109
# saving prediction for MELD_H18_3T_FCD_0115
# saving prediction for MELD_H18_3T_FCD_0124
# saving prediction for MELD_H19_3T_C_008
# saving prediction for MELD_H19_3T_C_014
# saving prediction for MELD_H19_3T_C_017
# saving prediction for MELD_H19_3T_C_018
# saving prediction for MELD_H19_3T_C_020
# saving prediction for MELD_H19_3T_C_024
# saving prediction for MELD_H19_3T_C_025
# saving prediction for MELD_H19_3T_C_026
# saving prediction for MELD_H19_3T_C_029
# saving prediction for MELD_H19_3T_C_031
# saving prediction for MELD_H21_15T_FCD_0036
# saving prediction for MELD_H21_15T_FCD_0038
# saving prediction for MELD_H21_15T_FCD_0040
# saving prediction for MELD_H21_15T_FCD_0043
# saving prediction for MELD_H21_15T_FCD_0047
# saving prediction for MELD_H21_15T_FCD_0049
# saving prediction for MELD_H21_15T_FCD_0050
# saving prediction for MELD_H21_15T_FCD_0051
# saving prediction for MELD_H21_15T_FCD_0052
# saving prediction for MELD_H21_3T_FCD_0007
# saving prediction for MELD_H21_3T_FCD_0008
# saving prediction for MELD_H21_3T_FCD_0009
# saving prediction for MELD_H21_3T_FCD_0013
# saving prediction for MELD_H21_3T_FCD_0016
# saving prediction for MELD_H21_3T_FCD_0017
# saving prediction for MELD_H21_3T_FCD_0018
# saving prediction for MELD_H21_3T_FCD_0030
# saving prediction for MELD_H21_3T_FCD_0033
# saving prediction for MELD_H21_3T_FCD_0034
# saving prediction for MELD_H21_3T_FCD_0035
# saving prediction for MELD_H21_3T_FCD_0046
# saving prediction for MELD_H21_3T_FCD_0048
# saving prediction for MELD_H23_15T_FCD_0003
# saving prediction for MELD_H23_15T_FCD_0004
# saving prediction for MELD_H23_15T_FCD_0005
# saving prediction for MELD_H23_15T_FCD_0011
# saving prediction for MELD_H23_15T_FCD_0013
# saving prediction for MELD_H23_15T_FCD_0015
# saving prediction for MELD_H23_15T_FCD_0020
# saving prediction for MELD_H23_15T_FCD_0021
# saving prediction for MELD_H23_15T_FCD_0022
# saving prediction for MELD_H23_15T_FCD_0023
# saving prediction for MELD_H23_15T_FCD_0025
# saving prediction for MELD_H23_15T_FCD_0027
# saving prediction for MELD_H23_15T_FCD_0030
# saving prediction for MELD_H23_15T_FCD_0031
# saving prediction for MELD_H23_15T_FCD_0032
# saving prediction for MELD_H24_3T_FCD_0003
# saving prediction for MELD_H24_3T_FCD_0005
# saving prediction for MELD_H24_3T_FCD_0006
# saving prediction for MELD_H24_3T_FCD_0007
# saving prediction for MELD_H24_3T_FCD_0011
# saving prediction for MELD_H24_3T_FCD_0012
# saving prediction for MELD_H24_3T_FCD_0013
# saving prediction for MELD_H24_3T_FCD_0015
# saving prediction for MELD_H24_3T_FCD_0025
# saving prediction for MELD_H24_3T_FCD_0026
# saving prediction for MELD_H24_3T_FCD_0029
# saving prediction for MELD_H24_3T_FCD_0030
# saving prediction for MELD_H24_3T_FCD_0036
# saving prediction for MELD_H24_3T_FCD_0037
# saving prediction for MELD_H24_3T_FCD_0040
# saving prediction for MELD_H24_3T_FCD_0041
# saving prediction for MELD_H26_15T_FCD_0001
# saving prediction for MELD_H26_15T_FCD_0005
# saving prediction for MELD_H26_15T_FCD_0009
# saving prediction for MELD_H26_15T_FCD_0010
# saving prediction for MELD_H26_3T_FCD_0002
# saving prediction for MELD_H26_3T_FCD_0004
# saving prediction for MELD_H26_3T_FCD_0007
# saving prediction for MELD_H2_15T_C_0001
# saving prediction for MELD_H2_15T_FCD_0001
# saving prediction for MELD_H2_15T_FCD_0003
# saving prediction for MELD_H2_15T_FCD_0005
# saving prediction for MELD_H2_15T_FCD_0007
# saving prediction for MELD_H2_15T_FCD_0008
# saving prediction for MELD_H2_15T_FCD_0009
# saving prediction for MELD_H2_15T_FCD_0014
# saving prediction for MELD_H2_15T_FCD_0015
# saving prediction for MELD_H2_15T_FCD_0016
# saving prediction for MELD_H2_15T_FCD_0020
# saving prediction for MELD_H2_15T_FCD_0023
# saving prediction for MELD_H2_15T_FCD_0028
# saving prediction for MELD_H2_15T_FCD_0029
# saving prediction for MELD_H2_15T_FCD_0030
# saving prediction for MELD_H2_3T_C_0001
# saving prediction for MELD_H2_3T_C_0003
# saving prediction for MELD_H2_3T_C_0007
# saving prediction for MELD_H2_3T_C_0008
# saving prediction for MELD_H2_3T_C_0009
# saving prediction for MELD_H2_3T_C_0012
# saving prediction for MELD_H2_3T_C_0013
# saving prediction for MELD_H2_3T_C_0014
# saving prediction for MELD_H2_3T_C_0017
# saving prediction for MELD_H2_3T_C_0019
# saving prediction for MELD_H2_3T_C_0020
# saving prediction for MELD_H2_3T_C_0021
# saving prediction for MELD_H2_3T_C_0025
# saving prediction for MELD_H2_3T_C_0027
# saving prediction for MELD_H2_3T_C_0029
# saving prediction for MELD_H2_3T_C_0030
# saving prediction for MELD_H2_3T_C_0031
# saving prediction for MELD_H2_3T_FCD_0003
# saving prediction for MELD_H2_3T_FCD_0004
# saving prediction for MELD_H2_3T_FCD_0005
# saving prediction for MELD_H2_3T_FCD_0006
# saving prediction for MELD_H2_3T_FCD_0008
# saving prediction for MELD_H2_3T_FCD_0014
# saving prediction for MELD_H2_3T_FCD_0016
# saving prediction for MELD_H2_3T_FCD_0017
# saving prediction for MELD_H2_3T_FCD_0018
# saving prediction for MELD_H3_3T_C_0003
# saving prediction for MELD_H3_3T_C_0004
# saving prediction for MELD_H3_3T_C_0010
# saving prediction for MELD_H3_3T_C_0011
# saving prediction for MELD_H3_3T_C_0012
# saving prediction for MELD_H3_3T_C_0013
# saving prediction for MELD_H3_3T_C_0016
# saving prediction for MELD_H3_3T_C_0017
# saving prediction for MELD_H3_3T_C_0021
# saving prediction for MELD_H3_3T_C_0023
# saving prediction for MELD_H3_3T_C_0028
# saving prediction for MELD_H3_3T_C_0034
# saving prediction for MELD_H3_3T_C_0035
# saving prediction for MELD_H3_3T_C_0036
# saving prediction for MELD_H3_3T_C_0038
# saving prediction for MELD_H3_3T_C_0039
# saving prediction for MELD_H3_3T_C_0040
# saving prediction for MELD_H3_3T_C_0042
# saving prediction for MELD_H3_3T_C_0043
# saving prediction for MELD_H3_3T_C_0044
# saving prediction for MELD_H3_3T_C_0047
# saving prediction for MELD_H3_3T_C_0048
# saving prediction for MELD_H3_3T_C_0051
# saving prediction for MELD_H3_3T_C_0058
# saving prediction for MELD_H3_3T_C_0061
# saving prediction for MELD_H3_3T_C_0066
# saving prediction for MELD_H3_3T_C_0067
# saving prediction for MELD_H3_3T_C_0068
# saving prediction for MELD_H3_3T_C_0070
# saving prediction for MELD_H3_3T_C_0071
# saving prediction for MELD_H3_3T_C_0072
# saving prediction for MELD_H3_3T_C_0075
# saving prediction for MELD_H3_3T_C_0076
# saving prediction for MELD_H3_3T_C_0077
# saving prediction for MELD_H3_3T_C_0079
# saving prediction for MELD_H3_3T_C_0080
# saving prediction for MELD_H3_3T_C_0081
# saving prediction for MELD_H3_3T_C_0082
# saving prediction for MELD_H3_3T_C_0084
# saving prediction for MELD_H3_3T_C_0085
# saving prediction for MELD_H3_3T_C_0088
# saving prediction for MELD_H3_3T_C_0095
# saving prediction for MELD_H3_3T_C_0096
# saving prediction for MELD_H3_3T_C_0099
# saving prediction for MELD_H3_3T_FCD_0002
# saving prediction for MELD_H3_3T_FCD_0003
# saving prediction for MELD_H3_3T_FCD_0004
# saving prediction for MELD_H3_3T_FCD_0005
# saving prediction for MELD_H3_3T_FCD_0007
# saving prediction for MELD_H3_3T_FCD_0008
# saving prediction for MELD_H3_3T_FCD_0009
# saving prediction for MELD_H3_3T_FCD_0010
# saving prediction for MELD_H3_3T_FCD_0012
# saving prediction for MELD_H3_3T_FCD_0014
# saving prediction for MELD_H3_3T_FCD_0015
# saving prediction for MELD_H3_3T_FCD_0016
# saving prediction for MELD_H3_3T_FCD_0018
# saving prediction for MELD_H3_3T_FCD_0020
# saving prediction for MELD_H3_3T_FCD_0022
# saving prediction for MELD_H3_3T_FCD_0023
# saving prediction for MELD_H4_15T_C_0001
# saving prediction for MELD_H4_15T_C_0002
# saving prediction for MELD_H4_15T_C_0007
# saving prediction for MELD_H4_15T_C_0011
# saving prediction for MELD_H4_15T_C_0012
# saving prediction for MELD_H4_15T_C_0014
# saving prediction for MELD_H4_15T_C_0018
# saving prediction for MELD_H4_15T_C_0020
# saving prediction for MELD_H4_15T_C_0022
# saving prediction for MELD_H4_15T_C_0024
# saving prediction for MELD_H4_15T_C_0025
# saving prediction for MELD_H4_15T_C_0026
# saving prediction for MELD_H4_15T_C_0029
# saving prediction for MELD_H4_15T_C_0030
# saving prediction for MELD_H4_15T_FCD_0002
# saving prediction for MELD_H4_15T_FCD_0003
# saving prediction for MELD_H4_15T_FCD_0009
# saving prediction for MELD_H4_15T_FCD_0016
# saving prediction for MELD_H4_15T_FCD_0017
# saving prediction for MELD_H4_15T_FCD_0018
# saving prediction for MELD_H4_15T_FCD_0019
# saving prediction for MELD_H4_15T_FCD_0020
# saving prediction for MELD_H4_15T_FCD_0021
# saving prediction for MELD_H4_3T_C_0001
# saving prediction for MELD_H4_3T_C_0007
# saving prediction for MELD_H4_3T_C_0009
# saving prediction for MELD_H4_3T_C_0010
# saving prediction for MELD_H4_3T_C_0012
# saving prediction for MELD_H4_3T_C_0013
# saving prediction for MELD_H4_3T_C_0015
# saving prediction for MELD_H4_3T_C_0016
# saving prediction for MELD_H4_3T_FCD_0002
# saving prediction for MELD_H4_3T_FCD_0005
# saving prediction for MELD_H4_3T_FCD_0007
# saving prediction for MELD_H4_3T_FCD_0009
# saving prediction for MELD_H4_3T_FCD_0010
# saving prediction for MELD_H4_3T_FCD_0015
# saving prediction for MELD_H4_3T_FCD_0016
# saving prediction for MELD_H4_3T_FCD_0031
# saving prediction for MELD_H4_3T_FCD_0038
# saving prediction for MELD_H4_3T_FCD_0040
# saving prediction for MELD_H5_3T_C_0001
# saving prediction for MELD_H5_3T_C_0002
# saving prediction for MELD_H5_3T_C_0004
# saving prediction for MELD_H5_3T_C_0006
# saving prediction for MELD_H5_3T_C_0007
# saving prediction for MELD_H5_3T_C_0009
# saving prediction for MELD_H5_3T_C_0010
# saving prediction for MELD_H5_3T_C_0011
# saving prediction for MELD_H5_3T_C_0012
# saving prediction for MELD_H5_3T_C_0014
# saving prediction for MELD_H5_3T_C_0015
# saving prediction for MELD_H5_3T_C_0016
# saving prediction for MELD_H5_3T_C_0017
# saving prediction for MELD_H5_3T_C_0018
# saving prediction for MELD_H5_3T_C_0019
# saving prediction for MELD_H5_3T_C_0021
# saving prediction for MELD_H5_3T_C_0025
# saving prediction for MELD_H5_3T_C_0027
# saving prediction for MELD_H5_3T_C_0029
# saving prediction for MELD_H5_3T_FCD_0001
# saving prediction for MELD_H5_3T_FCD_0004
# saving prediction for MELD_H5_3T_FCD_0005
# saving prediction for MELD_H5_3T_FCD_0006
# saving prediction for MELD_H5_3T_FCD_0007
# saving prediction for MELD_H5_3T_FCD_0009
# saving prediction for MELD_H5_3T_FCD_0011
# saving prediction for MELD_H5_3T_FCD_0013
# saving prediction for MELD_H5_3T_FCD_0014
# saving prediction for MELD_H5_3T_FCD_0015
# saving prediction for MELD_H5_3T_FCD_0017
# saving prediction for MELD_H5_3T_FCD_0020
# saving prediction for MELD_H5_3T_FCD_0021
# saving prediction for MELD_H5_3T_FCD_0022
# saving prediction for MELD_H5_3T_FCD_0024
# saving prediction for MELD_H5_3T_FCD_0025
# saving prediction for MELD_H5_3T_FCD_0026
# saving prediction for MELD_H5_3T_FCD_0029
# saving prediction for MELD_H6_3T_FCD_0004
# saving prediction for MELD_H6_3T_FCD_0005
# saving prediction for MELD_H6_3T_FCD_0006
# saving prediction for MELD_H6_3T_FCD_0008
# saving prediction for MELD_H6_3T_FCD_0009
# saving prediction for MELD_H6_3T_FCD_0011
# saving prediction for MELD_H6_3T_FCD_0013
# saving prediction for MELD_H6_3T_FCD_0014
# saving prediction for MELD_H6_3T_FCD_0015
# saving prediction for MELD_H6_3T_FCD_0017
# saving prediction for MELD_H6_3T_FCD_0019
# saving prediction for MELD_H9_3T_C_0002
# saving prediction for MELD_H9_3T_C_0005
# saving prediction for MELD_H9_3T_C_0007
# saving prediction for MELD_H9_3T_C_0009
# saving prediction for MELD_H9_3T_FCD_0003
# saving prediction for MELD_H9_3T_FCD_0004
# saving prediction for MELD_H9_3T_FCD_0005
# saving prediction for MELD_H9_3T_FCD_0010
# saving prediction for MELD_H5_3T_FCD_0032

# %%
len(eva.dataset.subject_ids)
# Out:
# 180

# %% [markdown]
# ### Compare models

# %%
# load results 
import pandas as pd

df={}
predicted={}
for model_name in model_base_paths.keys():  
    
    results_file = os.path.join(EXPERIMENT_PATH,f'22-10-21_synth_evaluation/{model_name}', 'results', 'test_results.csv')
    df[model_name] = pd.read_csv(results_file)

# %%
df[model_name]
# Out:
#                      ID  group  detected  dice_tp  dice_fp  dice_fn  dice_tn
# 0     MELD_H5_3T_C_0008   True      True     5923       43       43   287795
# 1     MELD_H3_3T_C_0008   True      True     3831       30       16   289927
# 2     MELD_H19_3T_C_016   True      True     1387       13     5720   286684
# 3    MELD_H4_15T_C_0017   True      True      380       54     5906   287464
# 4     MELD_H5_3T_C_0022   True      True     2183       60        0   291561
# ..                  ...    ...       ...      ...      ...      ...      ...
# 157   MELD_H4_3T_C_0019   True      True     1439      109       81   292175
# 158   MELD_H3_3T_C_0002   True      True     4814     2691      551   285748
# 159  MELD_H14_3T_C_0019   True      True    13269       87       22   280426
# 160   MELD_H5_3T_C_0028   True      True    29340       88       27   264349
# 161   MELD_H3_3T_C_0055   True      True     8540       83      383   284798
#
# [162 rows x 7 columns]

# %%
# stats
import pandas as pd

for model_name in model_base_paths.keys():  
   
    dfsub = df[model_name]    
    predicted = (dfsub['dice_tp']>0)
    print(f'Model {model_name}: \n {predicted.sum()/len(predicted)} sensitivity')
# Out:
# Model unet_deepsuper:
#  0.9382716049382716 sensitivity
# Model unet_small_scratch:
#  0.9259259259259259 sensitivity
# Model unet_small_finetune:
#  0.9691358024691358 sensitivity

# %%
# Out:
#                      ID  group  detected  dice_tp  dice_fp  dice_fn  dice_tn
# 0     MELD_H5_3T_C_0008   True      True     5923       43       43   287795
# 1     MELD_H3_3T_C_0008   True      True     3831       30       16   289927
# 2     MELD_H19_3T_C_016   True      True     1387       13     5720   286684
# 3    MELD_H4_15T_C_0017   True      True      380       54     5906   287464
# 4     MELD_H5_3T_C_0022   True      True     2183       60        0   291561
# ..                  ...    ...       ...      ...      ...      ...      ...
# 157   MELD_H4_3T_C_0019   True      True     1439      109       81   292175
# 158   MELD_H3_3T_C_0002   True      True     4814     2691      551   285748
# 159  MELD_H14_3T_C_0019   True      True    13269       87       22   280426
# 160   MELD_H5_3T_C_0028   True      True    29340       88       27   264349
# 161   MELD_H3_3T_C_0055   True      True     8540       83      383   284798
#
# [162 rows x 7 columns]

# %% [markdown]
# ### Plot prediction and lesion

# %%
import h5py
import matplotlib_surface_plotting as msp
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import nibabel as nb
from meld_classifier.paths import BASE_PATH

def load_prediction(subject,hdf5):
    results={}
    with h5py.File(hdf5, "r") as f:
        for hemi in ['lh','rh']:
            results[hemi] = f[subject][hemi]['prediction'][:]
    return results

def create_surface_plots(coords,faces,overlay,flat_map=True):
    """plot and reload surface images"""
    from meld_classifier.meld_plotting import trim
    import matplotlib_surface_plotting.matplotlib_surface_plotting as msp
    from PIL import Image

    msp.plot_surf(coords,faces, 
                overlay,
                flat_map=flat_map,
                rotate=[90, 270],
                filename='tmp.png',
                vmin=0.4,
                vmax=0.6,
             )
    im = Image.open('tmp.png')
    im = trim(im)
    im = im.convert("RGBA")
    im1 = np.array(im)
    return im1

# %%
cohort = MeldCohort(hdf5_file_root='{site_code}_{group}_featurematrix_combat_6.hdf5',
               dataset='MELD_dataset_V6.csv')



predictions_file = os.path.join('/rds/project/kw350/rds-kw350-meld/experiments_graph/kw350/22-10-21_real_evaluation2/unet_finetune_small_real/results/predictions.hdf5')

with h5py.File(predictions_file, "r") as f:
    subjects= list(f.keys())
subjects
# Out:
# ['MELD2_H7_3T_FCD_001',
#  'MELD2_H7_3T_FCD_002',
#  'MELD2_H7_3T_FCD_004',
#  'MELD2_H7_3T_FCD_005',
#  'MELD2_H7_3T_FCD_009',
#  'MELD2_H7_3T_FCD_011',
#  'MELD2_H7_3T_FCD_014',
#  'MELD_H10_3T_C_0005',
#  'MELD_H10_3T_C_0006',
#  'MELD_H10_3T_C_0009',
#  'MELD_H10_3T_C_0011',
#  'MELD_H10_3T_C_0012',
#  'MELD_H10_3T_C_0013',
#  'MELD_H10_3T_C_0014',
#  'MELD_H10_3T_C_0015',
#  'MELD_H10_3T_C_0017',
#  'MELD_H10_3T_C_0018',
#  'MELD_H10_3T_C_0019',
#  'MELD_H10_3T_C_0021',
#  'MELD_H10_3T_C_0022',
#  'MELD_H10_3T_C_0025',
#  'MELD_H10_3T_C_0028',
#  'MELD_H10_3T_C_0029',
#  'MELD_H10_3T_C_0031',
#  'MELD_H10_3T_FCD_0002',
#  'MELD_H10_3T_FCD_0009',
#  'MELD_H10_3T_FCD_0013',
#  'MELD_H10_3T_FCD_0014',
#  'MELD_H10_3T_FCD_0016',
#  'MELD_H11_3T_FCD_0002',
#  'MELD_H11_3T_FCD_0006',
#  'MELD_H11_3T_FCD_0007',
#  'MELD_H11_3T_FCD_0009',
#  'MELD_H11_3T_FCD_0010',
#  'MELD_H11_3T_FCD_0011',
#  'MELD_H11_3T_FCD_0015',
#  'MELD_H11_3T_FCD_0019',
#  'MELD_H11_3T_FCD_0020',
#  'MELD_H11_3T_FCD_0025',
#  'MELD_H11_3T_FCD_0027',
#  'MELD_H11_3T_FCD_0028',
#  'MELD_H11_3T_FCD_0030',
#  'MELD_H11_3T_FCD_0031',
#  'MELD_H11_3T_FCD_0040',
#  'MELD_H11_3T_FCD_0041',
#  'MELD_H11_3T_FCD_0042',
#  'MELD_H11_3T_FCD_0044',
#  'MELD_H11_3T_FCD_0045',
#  'MELD_H12_15T_FCD_0001',
#  'MELD_H12_15T_FCD_0003',
#  'MELD_H12_15T_FCD_0005',
#  'MELD_H12_3T_C_0002',
#  'MELD_H12_3T_C_0004',
#  'MELD_H12_3T_C_0005',
#  'MELD_H12_3T_C_0007',
#  'MELD_H12_3T_C_0010',
#  'MELD_H12_3T_C_0011',
#  'MELD_H12_3T_C_0014',
#  'MELD_H12_3T_C_0016',
#  'MELD_H12_3T_C_0018',
#  'MELD_H12_3T_C_0023',
#  'MELD_H12_3T_C_0024',
#  'MELD_H12_3T_C_0025',
#  'MELD_H12_3T_C_0026',
#  'MELD_H12_3T_C_0028',
#  'MELD_H12_3T_C_0029',
#  'MELD_H12_3T_C_0031',
#  'MELD_H12_3T_C_0032',
#  'MELD_H12_3T_C_0034',
#  'MELD_H12_3T_C_0035',
#  'MELD_H12_3T_C_0036',
#  'MELD_H12_3T_C_0037',
#  'MELD_H12_3T_C_0038',
#  'MELD_H12_3T_C_0040',
#  'MELD_H12_3T_C_0041',
#  'MELD_H12_3T_C_0042',
#  'MELD_H12_3T_C_0044',
#  'MELD_H12_3T_C_0045',
#  'MELD_H12_3T_C_0050',
#  'MELD_H12_3T_C_0051',
#  'MELD_H12_3T_C_0052',
#  'MELD_H12_3T_FCD_0003',
#  'MELD_H12_3T_FCD_0006',
#  'MELD_H12_3T_FCD_0007',
#  'MELD_H12_3T_FCD_0009',
#  'MELD_H12_3T_FCD_0011',
#  'MELD_H12_3T_FCD_0014',
#  'MELD_H12_3T_FCD_0016',
#  'MELD_H12_3T_FCD_0018',
#  'MELD_H12_3T_FCD_0023',
#  'MELD_H12_3T_FCD_0024',
#  'MELD_H12_3T_FCD_0030',
#  'MELD_H12_3T_FCD_0031',
#  'MELD_H14_3T_C_0001',
#  'MELD_H14_3T_C_0002',
#  'MELD_H14_3T_C_0003',
#  'MELD_H14_3T_C_0005',
#  'MELD_H14_3T_C_0010',
#  'MELD_H14_3T_C_0012',
#  'MELD_H14_3T_C_0014',
#  'MELD_H14_3T_C_0015',
#  'MELD_H14_3T_C_0016',
#  'MELD_H14_3T_C_0017',
#  'MELD_H14_3T_C_0019',
#  'MELD_H14_3T_C_0020',
#  'MELD_H14_3T_C_0021',
#  'MELD_H14_3T_C_0024',
#  'MELD_H14_3T_C_0025',
#  'MELD_H14_3T_FCD_0009',
#  'MELD_H14_3T_FCD_0011',
#  'MELD_H14_3T_FCD_0013',
#  'MELD_H14_3T_FCD_0016',
#  'MELD_H14_3T_FCD_0017',
#  'MELD_H14_3T_FCD_0021',
#  'MELD_H14_3T_FCD_0022',
#  'MELD_H14_3T_FCD_0023',
#  'MELD_H14_3T_FCD_0024',
#  'MELD_H14_3T_FCD_0025',
#  'MELD_H14_3T_FCD_0026',
#  'MELD_H14_3T_FCD_0029',
#  'MELD_H14_3T_FCD_0030',
#  'MELD_H14_3T_FCD_0031',
#  'MELD_H14_3T_FCD_0034',
#  'MELD_H14_3T_FCD_0035',
#  'MELD_H14_3T_FCD_0037',
#  'MELD_H14_3T_FCD_0039',
#  'MELD_H14_3T_FCD_0040',
#  'MELD_H14_3T_FCD_0042',
#  'MELD_H15_3T_C_0001',
#  'MELD_H15_3T_C_0006',
#  'MELD_H15_3T_C_0007',
#  'MELD_H15_3T_C_0012',
#  'MELD_H15_3T_C_0013',
#  'MELD_H15_3T_C_0015',
#  'MELD_H15_3T_C_0018',
#  'MELD_H15_3T_C_0019',
#  'MELD_H15_3T_C_0025',
#  'MELD_H15_3T_C_0027',
#  'MELD_H15_3T_C_0030',
#  'MELD_H15_3T_C_0031',
#  'MELD_H15_3T_C_0032',
#  'MELD_H15_3T_C_0033',
#  'MELD_H15_3T_FCD_0003',
#  'MELD_H15_3T_FCD_0004',
#  'MELD_H15_3T_FCD_0007',
#  'MELD_H15_3T_FCD_0008',
#  'MELD_H15_3T_FCD_0010',
#  'MELD_H16_3T_FCD_001',
#  'MELD_H16_3T_FCD_003',
#  'MELD_H16_3T_FCD_004',
#  'MELD_H16_3T_FCD_005',
#  'MELD_H16_3T_FCD_008',
#  'MELD_H16_3T_FCD_010',
#  'MELD_H16_3T_FCD_013',
#  'MELD_H16_3T_FCD_015',
#  'MELD_H16_3T_FCD_016',
#  'MELD_H16_3T_FCD_017',
#  'MELD_H16_3T_FCD_022',
#  'MELD_H16_3T_FCD_023',
#  'MELD_H16_3T_FCD_026',
#  'MELD_H16_3T_FCD_045',
#  'MELD_H16_3T_FCD_048',
#  'MELD_H17_15T_FCD_0011',
#  'MELD_H17_15T_FCD_0017',
#  'MELD_H17_15T_FCD_0102',
#  'MELD_H17_15T_FCD_0104',
#  'MELD_H17_15T_FCD_0139',
#  'MELD_H17_3T_FCD_0001',
#  'MELD_H17_3T_FCD_0014',
#  'MELD_H17_3T_FCD_0018',
#  'MELD_H17_3T_FCD_0022',
#  'MELD_H17_3T_FCD_0039',
#  'MELD_H17_3T_FCD_0043',
#  'MELD_H17_3T_FCD_0044',
#  'MELD_H17_3T_FCD_0053',
#  'MELD_H17_3T_FCD_0054',
#  'MELD_H17_3T_FCD_0057',
#  'MELD_H17_3T_FCD_0061',
#  'MELD_H17_3T_FCD_0067',
#  'MELD_H17_3T_FCD_0070',
#  'MELD_H17_3T_FCD_0076',
#  'MELD_H17_3T_FCD_0079',
#  'MELD_H17_3T_FCD_0084',
#  'MELD_H17_3T_FCD_0086',
#  'MELD_H17_3T_FCD_0090',
#  'MELD_H17_3T_FCD_0091',
#  'MELD_H17_3T_FCD_0094',
#  'MELD_H17_3T_FCD_0098',
#  'MELD_H17_3T_FCD_0112',
#  'MELD_H17_3T_FCD_0116',
#  'MELD_H17_3T_FCD_0120',
#  'MELD_H17_3T_FCD_0127',
#  'MELD_H17_3T_FCD_0135',
#  'MELD_H17_3T_FCD_0143',
#  'MELD_H18_3T_FCD_0001',
#  'MELD_H18_3T_FCD_0006',
#  'MELD_H18_3T_FCD_0008',
#  'MELD_H18_3T_FCD_0009',
#  'MELD_H18_3T_FCD_0101',
#  'MELD_H18_3T_FCD_0109',
#  'MELD_H18_3T_FCD_0115',
#  'MELD_H18_3T_FCD_0124',
#  'MELD_H19_3T_C_008',
#  'MELD_H19_3T_C_014',
#  'MELD_H19_3T_C_017',
#  'MELD_H19_3T_C_018',
#  'MELD_H19_3T_C_020',
#  'MELD_H19_3T_C_024',
#  'MELD_H19_3T_C_025',
#  'MELD_H19_3T_C_026',
#  'MELD_H19_3T_C_029',
#  'MELD_H19_3T_C_031',
#  'MELD_H21_15T_FCD_0036',
#  'MELD_H21_15T_FCD_0038',
#  'MELD_H21_15T_FCD_0040',
#  'MELD_H21_15T_FCD_0043',
#  'MELD_H21_15T_FCD_0047',
#  'MELD_H21_15T_FCD_0049',
#  'MELD_H21_15T_FCD_0050',
#  'MELD_H21_15T_FCD_0051',
#  'MELD_H21_15T_FCD_0052',
#  'MELD_H21_3T_FCD_0007',
#  'MELD_H21_3T_FCD_0008',
#  'MELD_H21_3T_FCD_0009',
#  'MELD_H21_3T_FCD_0013',
#  'MELD_H21_3T_FCD_0016',
#  'MELD_H21_3T_FCD_0017',
#  'MELD_H21_3T_FCD_0018',
#  'MELD_H21_3T_FCD_0030',
#  'MELD_H21_3T_FCD_0033',
#  'MELD_H21_3T_FCD_0034',
#  'MELD_H21_3T_FCD_0035',
#  'MELD_H21_3T_FCD_0046',
#  'MELD_H21_3T_FCD_0048',
#  'MELD_H23_15T_FCD_0003',
#  'MELD_H23_15T_FCD_0004',
#  'MELD_H23_15T_FCD_0005',
#  'MELD_H23_15T_FCD_0011',
#  'MELD_H23_15T_FCD_0013',
#  'MELD_H23_15T_FCD_0015',
#  'MELD_H23_15T_FCD_0020',
#  'MELD_H23_15T_FCD_0021',
#  'MELD_H23_15T_FCD_0022',
#  'MELD_H23_15T_FCD_0023',
#  'MELD_H23_15T_FCD_0025',
#  'MELD_H23_15T_FCD_0027',
#  'MELD_H23_15T_FCD_0030',
#  'MELD_H23_15T_FCD_0031',
#  'MELD_H23_15T_FCD_0032',
#  'MELD_H24_3T_FCD_0003',
#  'MELD_H24_3T_FCD_0005',
#  'MELD_H24_3T_FCD_0006',
#  'MELD_H24_3T_FCD_0007',
#  'MELD_H24_3T_FCD_0011',
#  'MELD_H24_3T_FCD_0012',
#  'MELD_H24_3T_FCD_0013',
#  'MELD_H24_3T_FCD_0015',
#  'MELD_H24_3T_FCD_0025',
#  'MELD_H24_3T_FCD_0026',
#  'MELD_H24_3T_FCD_0029',
#  'MELD_H24_3T_FCD_0030',
#  'MELD_H24_3T_FCD_0036',
#  'MELD_H24_3T_FCD_0037',
#  'MELD_H24_3T_FCD_0040',
#  'MELD_H24_3T_FCD_0041',
#  'MELD_H26_15T_FCD_0001',
#  'MELD_H26_15T_FCD_0005',
#  'MELD_H26_15T_FCD_0009',
#  'MELD_H26_15T_FCD_0010',
#  'MELD_H26_3T_FCD_0002',
#  'MELD_H26_3T_FCD_0004',
#  'MELD_H26_3T_FCD_0007',
#  'MELD_H2_15T_C_0001',
#  'MELD_H2_15T_FCD_0001',
#  'MELD_H2_15T_FCD_0003',
#  'MELD_H2_15T_FCD_0005',
#  'MELD_H2_15T_FCD_0007',
#  'MELD_H2_15T_FCD_0008',
#  'MELD_H2_15T_FCD_0009',
#  'MELD_H2_15T_FCD_0014',
#  'MELD_H2_15T_FCD_0015',
#  'MELD_H2_15T_FCD_0016',
#  'MELD_H2_15T_FCD_0020',
#  'MELD_H2_15T_FCD_0023',
#  'MELD_H2_15T_FCD_0028',
#  'MELD_H2_15T_FCD_0029',
#  'MELD_H2_15T_FCD_0030',
#  'MELD_H2_3T_C_0001',
#  'MELD_H2_3T_C_0003',
#  'MELD_H2_3T_C_0007',
#  'MELD_H2_3T_C_0008',
#  'MELD_H2_3T_C_0009',
#  'MELD_H2_3T_C_0012',
#  'MELD_H2_3T_C_0013',
#  'MELD_H2_3T_C_0014',
#  'MELD_H2_3T_C_0017',
#  'MELD_H2_3T_C_0019',
#  'MELD_H2_3T_C_0020',
#  'MELD_H2_3T_C_0021',
#  'MELD_H2_3T_C_0025',
#  'MELD_H2_3T_C_0027',
#  'MELD_H2_3T_C_0029',
#  'MELD_H2_3T_C_0030',
#  'MELD_H2_3T_C_0031',
#  'MELD_H2_3T_FCD_0003',
#  'MELD_H2_3T_FCD_0004',
#  'MELD_H2_3T_FCD_0005',
#  'MELD_H2_3T_FCD_0006',
#  'MELD_H2_3T_FCD_0008',
#  'MELD_H2_3T_FCD_0014',
#  'MELD_H2_3T_FCD_0016',
#  'MELD_H2_3T_FCD_0017',
#  'MELD_H2_3T_FCD_0018',
#  'MELD_H3_3T_C_0003',
#  'MELD_H3_3T_C_0004',
#  'MELD_H3_3T_C_0010',
#  'MELD_H3_3T_C_0011',
#  'MELD_H3_3T_C_0012',
#  'MELD_H3_3T_C_0013',
#  'MELD_H3_3T_C_0016',
#  'MELD_H3_3T_C_0017',
#  'MELD_H3_3T_C_0021',
#  'MELD_H3_3T_C_0023',
#  'MELD_H3_3T_C_0028',
#  'MELD_H3_3T_C_0034',
#  'MELD_H3_3T_C_0035',
#  'MELD_H3_3T_C_0036',
#  'MELD_H3_3T_C_0038',
#  'MELD_H3_3T_C_0039',
#  'MELD_H3_3T_C_0040',
#  'MELD_H3_3T_C_0042',
#  'MELD_H3_3T_C_0043',
#  'MELD_H3_3T_C_0044',
#  'MELD_H3_3T_C_0047',
#  'MELD_H3_3T_C_0048',
#  'MELD_H3_3T_C_0051',
#  'MELD_H3_3T_C_0058',
#  'MELD_H3_3T_C_0061',
#  'MELD_H3_3T_C_0066',
#  'MELD_H3_3T_C_0067',
#  'MELD_H3_3T_C_0068',
#  'MELD_H3_3T_C_0070',
#  'MELD_H3_3T_C_0071',
#  'MELD_H3_3T_C_0072',
#  'MELD_H3_3T_C_0075',
#  'MELD_H3_3T_C_0076',
#  'MELD_H3_3T_C_0077',
#  'MELD_H3_3T_C_0079',
#  'MELD_H3_3T_C_0080',
#  'MELD_H3_3T_C_0081',
#  'MELD_H3_3T_C_0082',
#  'MELD_H3_3T_C_0084',
#  'MELD_H3_3T_C_0085',
#  'MELD_H3_3T_C_0088',
#  'MELD_H3_3T_C_0095',
#  'MELD_H3_3T_C_0096',
#  'MELD_H3_3T_C_0099',
#  'MELD_H3_3T_FCD_0002',
#  'MELD_H3_3T_FCD_0003',
#  'MELD_H3_3T_FCD_0004',
#  'MELD_H3_3T_FCD_0005',
#  'MELD_H3_3T_FCD_0007',
#  'MELD_H3_3T_FCD_0008',
#  'MELD_H3_3T_FCD_0009',
#  'MELD_H3_3T_FCD_0010',
#  'MELD_H3_3T_FCD_0012',
#  'MELD_H3_3T_FCD_0014',
#  'MELD_H3_3T_FCD_0015',
#  'MELD_H3_3T_FCD_0016',
#  'MELD_H3_3T_FCD_0018',
#  'MELD_H3_3T_FCD_0020',
#  'MELD_H3_3T_FCD_0022',
#  'MELD_H3_3T_FCD_0023',
#  'MELD_H4_15T_C_0001',
#  'MELD_H4_15T_C_0002',
#  'MELD_H4_15T_C_0007',
#  'MELD_H4_15T_C_0011',
#  'MELD_H4_15T_C_0012',
#  'MELD_H4_15T_C_0014',
#  'MELD_H4_15T_C_0018',
#  'MELD_H4_15T_C_0020',
#  'MELD_H4_15T_C_0022',
#  'MELD_H4_15T_C_0024',
#  'MELD_H4_15T_C_0025',
#  'MELD_H4_15T_C_0026',
#  'MELD_H4_15T_C_0029',
#  'MELD_H4_15T_C_0030',
#  'MELD_H4_15T_FCD_0002',
#  'MELD_H4_15T_FCD_0003',
#  'MELD_H4_15T_FCD_0009',
#  'MELD_H4_15T_FCD_0016',
#  'MELD_H4_15T_FCD_0017',
#  'MELD_H4_15T_FCD_0018',
#  'MELD_H4_15T_FCD_0019',
#  'MELD_H4_15T_FCD_0020',
#  'MELD_H4_15T_FCD_0021',
#  'MELD_H4_3T_C_0001',
#  'MELD_H4_3T_C_0007',
#  'MELD_H4_3T_C_0009',
#  'MELD_H4_3T_C_0010',
#  'MELD_H4_3T_C_0012',
#  'MELD_H4_3T_C_0013',
#  'MELD_H4_3T_C_0015',
#  'MELD_H4_3T_C_0016',
#  'MELD_H4_3T_FCD_0002',
#  'MELD_H4_3T_FCD_0005',
#  'MELD_H4_3T_FCD_0007',
#  'MELD_H4_3T_FCD_0009',
#  'MELD_H4_3T_FCD_0010',
#  'MELD_H4_3T_FCD_0015',
#  'MELD_H4_3T_FCD_0016',
#  'MELD_H4_3T_FCD_0031',
#  'MELD_H4_3T_FCD_0038',
#  'MELD_H4_3T_FCD_0040',
#  'MELD_H5_3T_C_0001',
#  'MELD_H5_3T_C_0002',
#  'MELD_H5_3T_C_0004',
#  'MELD_H5_3T_C_0006',
#  'MELD_H5_3T_C_0007',
#  'MELD_H5_3T_C_0009',
#  'MELD_H5_3T_C_0010',
#  'MELD_H5_3T_C_0011',
#  'MELD_H5_3T_C_0012',
#  'MELD_H5_3T_C_0014',
#  'MELD_H5_3T_C_0015',
#  'MELD_H5_3T_C_0016',
#  'MELD_H5_3T_C_0017',
#  'MELD_H5_3T_C_0018',
#  'MELD_H5_3T_C_0019',
#  'MELD_H5_3T_C_0021',
#  'MELD_H5_3T_C_0025',
#  'MELD_H5_3T_C_0027',
#  'MELD_H5_3T_C_0029',
#  'MELD_H5_3T_FCD_0001',
#  'MELD_H5_3T_FCD_0004',
#  'MELD_H5_3T_FCD_0005',
#  'MELD_H5_3T_FCD_0006',
#  'MELD_H5_3T_FCD_0007',
#  'MELD_H5_3T_FCD_0009',
#  'MELD_H5_3T_FCD_0011',
#  'MELD_H5_3T_FCD_0013',
#  'MELD_H5_3T_FCD_0014',
#  'MELD_H5_3T_FCD_0015',
#  'MELD_H5_3T_FCD_0017',
#  'MELD_H5_3T_FCD_0020',
#  'MELD_H5_3T_FCD_0021',
#  'MELD_H5_3T_FCD_0022',
#  'MELD_H5_3T_FCD_0024',
#  'MELD_H5_3T_FCD_0025',
#  'MELD_H5_3T_FCD_0026',
#  'MELD_H5_3T_FCD_0029',
#  'MELD_H5_3T_FCD_0032',
#  'MELD_H6_3T_FCD_0004',
#  'MELD_H6_3T_FCD_0005',
#  'MELD_H6_3T_FCD_0006',
#  'MELD_H6_3T_FCD_0008',
#  'MELD_H6_3T_FCD_0009',
#  'MELD_H6_3T_FCD_0011',
#  'MELD_H6_3T_FCD_0013',
#  'MELD_H6_3T_FCD_0014',
#  'MELD_H6_3T_FCD_0015',
#  'MELD_H6_3T_FCD_0017',
#  'MELD_H6_3T_FCD_0019',
#  'MELD_H9_3T_C_0002',
#  'MELD_H9_3T_C_0005',
#  'MELD_H9_3T_C_0007',
#  'MELD_H9_3T_C_0009',
#  'MELD_H9_3T_FCD_0003',
#  'MELD_H9_3T_FCD_0004',
#  'MELD_H9_3T_FCD_0005',
#  'MELD_H9_3T_FCD_0010']

# %%
subjects=[
    'MELD2_H7_3T_FCD_004','MELD2_H7_3T_FCD_011', 'MELD_H14_3T_FCD_0025', 'MELD_H14_3T_FCD_0042', 
    'MELD_H14_3T_FCD_0040']

# %%
from numpy import False_


features=['none']
for subject in subjects:
    print(subject)
    result_hemis = load_prediction(subject,predictions_file)
    subj = MeldSubject(subject,cohort=c)
    labels_hemis = {}
    for hemi in ['lh','rh']:
        _, labels_hemis[hemi] = subj.load_feature_lesion_data(
            features, hemi=hemi, features_to_ignore=[]
        )

    #plot lesion
    flat = nb.load(os.path.join(BASE_PATH, "fsaverage_sym", "surf", "lh.full.patch.flat.gii"))
    coords, faces = flat.darrays[0].data, flat.darrays[1].data

    # round up to get the square grid size
    fig= plt.figure(figsize=(8,8), constrained_layout=True, facecolor='white')
    gs1 = GridSpec(2, 2, width_ratios=[1, 1],  wspace=0.1, hspace=0.1)
    data_to_plot= [result_hemis['lh'], result_hemis['rh'], labels_hemis['lh'], labels_hemis['rh']]
    titles=['predictions left hemi', 'predictions right hemi', 'labels left hemi', 'labels right hemi']
    for i,overlay in enumerate(data_to_plot):
        if len(overlay) < len(cohort.cortex_mask):
                overlay_tmp=np.zeros(len(cohort.cortex_mask))
                overlay_tmp[cohort.cortex_mask]= overlay
                overlay=overlay_tmp
        ax = fig.add_subplot(gs1[i])
        im = create_surface_plots(coords,faces,overlay,flat_map=True)
        ax.imshow(im)
        ax.axis('off')
        ax.set_title(titles[i], loc='left', fontsize=20)  
    fig.savefig(f'/rds/project/kw350/rds-kw350-meld/experiments_graph/kw350/22-10-21_real_evaluation2/unet_finetune_small_real/results/images/{subject}', bbox_inches='tight', transparent=False, facecolor=fig.get_facecolor())
    plt.close("all")
    fig.show()
# Out:
# MELD2_H7_3T_FCD_004
# /tmp/ipykernel_114928/1626536671.py:34: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   fig.savefig(f'/rds/project/kw350/rds-kw350-meld/experiments_graph/kw350/22-10-21_real_evaluation2/unet_finetune_small_real/results/images/{subject}', bbox_inches='tight', transparent=False, facecolor=fig.get_facecolor())
# MELD2_H7_3T_FCD_011
# MELD_H14_3T_FCD_0025
# MELD_H14_3T_FCD_0042
# MELD_H14_3T_FCD_0040

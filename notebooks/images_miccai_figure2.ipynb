# %% [markdown]
# Notebook to plot images for figure 2 for MICCAI submission

# %%
import numpy as np
import logging
import random
# import logging
# logging.basicConfig(level=logging.DEBUG)

from meld_classifier.meld_cohort import MeldCohort
from meld_graph.dataset import GraphDataset
# Out:
# Setting MELD_DATA_PATH to /rds/project/kw350/rds-kw350-meld/meld_data/Data
# Setting BASE_PATH to /rds/project/kw350/rds-kw350-meld/meld_data/Data
# Setting EXPERIMENT_PATH to /rds/project/kw350/rds-kw350-meld/experiments/co-ripa1/
# Setting FS_SUBJECTS_PATH to
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:matplotlib:matplotlib data path: /home/co-ripa1/.conda/envs/meld_graph/lib/python3.9/site-packages/matplotlib/mpl-data
# DEBUG:matplotlib:CONFIGDIR=/home/co-ripa1/.config/matplotlib
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# DEBUG:matplotlib:loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', '_io', 'marshal', 'posix', '_frozen_importlib_external', 'time', 'zipimport', '_codecs', 'codecs', 'encodings.aliases', 'encodings', 'encodings.utf_8', '_signal', 'encodings.latin_1', '_abc', 'abc', 'io', '__main__', '_stat', 'stat', '_collections_abc', 'genericpath', 'posixpath', 'os.path', 'os', '_sitebuiltins', '_locale', '_bootlocale', '_distutils_hack', 'types', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib', 'importlib.machinery', '_heapq', 'heapq', 'itertools', 'keyword', '_operator', 'operator', 'reprlib', '_collections', 'collections', 'collections.abc', '_functools', 'functools', 'contextlib', 'enum', '_sre', 'sre_constants', 'sre_parse', 'sre_compile', 'copyreg', 're', 'typing.io', 'typing.re', 'typing', 'importlib.abc', 'importlib.util', 'google', 'mpl_toolkits', 'site', '_weakrefset', 'weakref', 'pkgutil', 'runpy', 'ipykernel._version', '_json', 'json.scanner', 'json.decoder', 'json.encoder', 'json', 'errno', 'signal', 'threading', 'pwd', 'grp', '_posixsubprocess', 'select', 'math', 'selectors', 'subprocess', 'jupyter_client._version', '_ast', 'ast', '_opcode', 'opcode', 'dis', 'token', 'tokenize', 'linecache', 'inspect', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets.utils.descriptions', 'traitlets.traitlets', 'copy', 'traitlets.utils.decorators', 'traitlets._version', 'traitlets', 'concurrent', 'traceback', '_string', 'string', 'atexit', 'logging', 'concurrent.futures._base', 'concurrent.futures', '_socket', 'array', 'socket', '_ssl', '_struct', 'struct', 'binascii', 'base64', 'ssl', 'asyncio.constants', 'asyncio.format_helpers', 'asyncio.base_futures', 'asyncio.log', 'asyncio.coroutines', '_contextvars', 'contextvars', 'asyncio.exceptions', 'asyncio.base_tasks', '_asyncio', 'asyncio.events', 'asyncio.futures', 'asyncio.protocols', 'asyncio.transports', 'asyncio.sslproto', 'asyncio.locks', 'asyncio.tasks', 'asyncio.staggered', 'asyncio.trsock', 'asyncio.base_events', 'asyncio.runners', 'asyncio.queues', 'asyncio.streams', 'asyncio.subprocess', 'asyncio.threads', 'asyncio.base_subprocess', 'asyncio.selector_events', 'asyncio.unix_events', 'asyncio', '_queue', 'queue', 'platform', '_ctypes', 'ctypes._endian', 'ctypes', 'zmq.backend.select', 'cython_runtime', 'zmq.backend.cython.constants', '_cython_0_29_24', 'zmq.backend.cython.error', 'zmq.error', 'zmq.backend.cython.message', 'zmq.backend.cython.context', '_bisect', 'bisect', '_random', '_sha512', 'random', '_compat_pickle', '_pickle', 'pickle', 'zmq.backend.cython.socket', 'zmq.backend.cython.utils', 'zmq.backend.cython._poll', 'zmq.backend.cython._version', 'zmq.backend.cython._device', 'zmq.backend.cython._proxy_steerable', 'zmq.backend.cython', 'zmq.backend', 'zmq.utils', 'zmq.utils.constant_names', 'zmq.sugar.constants', 'zmq.sugar.attrsettr', 'zmq.sugar.poll', 'zmq.utils.jsonapi', 'zmq.utils.strtypes', 'zmq.sugar.socket', 'zmq.sugar.context', 'zmq.sugar.frame', 'zmq.sugar.tracker', 'zmq.sugar.version', 'zmq.sugar.stopwatch', 'zmq.sugar', 'zmq', 'zmq._future', 'zmq.asyncio', 'jupyter_client.channelsabc', '_hashlib', '_blake2', 'hashlib', 'hmac', 'pprint', '_datetime', 'datetime', 'gettext', 'argparse', 'traitlets.config.loader', 'textwrap', 'traitlets.utils.text', 'traitlets.config.configurable', 'traitlets.config.application', 'traitlets.config', 'traitlets.log', '__future__', 'tornado', 'logging.handlers', 'html.entities', 'html', 'urllib', 'urllib.parse', 'zlib', 'tornado.speedups', 'tornado.util', 'tornado.escape', '_curses', 'curses', 'tornado.log', 'numbers', 'tornado.concurrent', 'tornado.ioloop', 'tornado.platform', 'tornado.gen', 'tornado.platform.asyncio', 'zmq.eventloop.ioloop', 'zmq.eventloop', 'zmq.eventloop.zmqstream', 'jupyter_client.adapter', 'dateutil._version', 'dateutil', 'locale', 'calendar', ...
# DEBUG:matplotlib:CACHEDIR=/home/co-ripa1/.cache/matplotlib
# DEBUG:matplotlib.font_manager:Using fontManager instance from /home/co-ripa1/.cache/matplotlib/fontlist-v330.json
# DEBUG:matplotlib.pyplot:Loaded backend module://matplotlib_inline.backend_inline version unknown.
# DEBUG:matplotlib.pyplot:Loaded backend module://matplotlib_inline.backend_inline version unknown.
# Setting EXPERIMENT_PATH to /rds/project/kw350/rds-kw350-meld/experiments_graph/kw350

# %% [markdown]
# ### Plot synthetic

# %%
# initialise data_parameters

data_parameters = {
    "augment_data": {
    },
    "combine_hemis": None,
    "dataset": "MELD_dataset_V6.csv",
    "features": [
        # '.inter_z.asym.intra_z.combat.on_lh.pial.K_filtered.sm20.mgh',
        '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh',
        '.inter_z.asym.intra_z.combat.on_lh.thickness.sm10.mgh',
        '.inter_z.asym.intra_z.combat.on_lh.w-g.pct.sm10.mgh',
        ],
    "features_to_exclude": [],
    "features_to_replace_with_0": [],
    "fold_n": 0,
    "group": "control",
    "hdf5_file_root": "{site_code}_{group}_featurematrix_combat_6.hdf5",
    "icosphere_parameters": {"distance_type": "exact"},
    "lesion_bias": 0,
    "lobes": False,
    "number_of_folds": 5,
    "preprocessing_parameters": {
        "scaling": None,
        "zscore": "../data/feature_means.json",
    },
    "scanners": ["15T", "3T"],
    "site_codes": [
         "H4",
    ],
    "smooth_labels": True,
    "subject_features_to_exclude": [],
    "synthetic_data": {
        "bias": 1,
        "jitter_factor": 2,
        "n_subs": 500,
        "n_subtypes": 1,
        "proportion_features_abnormal": 1,
        "proportion_hemispheres_lesional": 0.5,
        "radius": 0.5,
        "run_synthetic": True,
        "smooth_lesion": False,
        "use_controls": True,
    },
}

cohort = MeldCohort(
            hdf5_file_root=data_parameters["hdf5_file_root"], dataset=data_parameters["dataset"]
        )
controls = cohort.get_subject_ids(group='control')
patients = cohort.get_subject_ids(group='patient')
# Out:
# INFO:meld_classifier.meld_cohort:total number of subjects: 373
# INFO:meld_classifier.meld_cohort:total number of subjects after restricting to subjects from MELD_dataset_V6.csv: 373
# INFO:meld_classifier.meld_cohort:total number of subjects: 950
# INFO:meld_classifier.meld_cohort:total number of subjects after restricting to subjects from MELD_dataset_V6.csv: 942
# DEBUG:meld_classifier.meld_cohort:selecting subjects that have features: []
# DEBUG:meld_classifier.meld_cohort:selecting subjects that don't have features: []
# INFO:meld_classifier.meld_cohort:total number after filtering by scanner ['3T', '15T'], features, lesional_only True: 911
# INFO:meld_classifier.meld_cohort:full_feature_list: ['.combat.on_lh.curv.sm5.mgh', '.combat.on_lh.gm_FLAIR_0.25.sm10.mgh', '.combat.on_lh.gm_FLAIR_0.5.sm10.mgh', '.combat.on_lh.gm_FLAIR_0.75.sm10.mgh', '.combat.on_lh.gm_FLAIR_0.sm10.mgh', '.combat.on_lh.pial.K_filtered.sm20.mgh', '.combat.on_lh.sulc.sm5.mgh', '.combat.on_lh.thickness.sm10.mgh', '.combat.on_lh.w-g.pct.sm10.mgh', '.combat.on_lh.wm_FLAIR_0.5.sm10.mgh', '.combat.on_lh.wm_FLAIR_1.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.curv.sm5.mgh', '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.25.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.5.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.pial.K_filtered.sm20.mgh', '.inter_z.asym.intra_z.combat.on_lh.sulc.sm5.mgh', '.inter_z.asym.intra_z.combat.on_lh.thickness.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.w-g.pct.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.wm_FLAIR_0.5.sm10.mgh', '.inter_z.asym.intra_z.combat.on_lh.wm_FLAIR_1.sm10.mgh', '.inter_z.intra_z.combat.on_lh.curv.sm5.mgh', '.inter_z.intra_z.combat.on_lh.gm_FLAIR_0.25.sm10.mgh', '.inter_z.intra_z.combat.on_lh.gm_FLAIR_0.5.sm10.mgh', '.inter_z.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh', '.inter_z.intra_z.combat.on_lh.gm_FLAIR_0.sm10.mgh', '.inter_z.intra_z.combat.on_lh.pial.K_filtered.sm20.mgh', '.inter_z.intra_z.combat.on_lh.sulc.sm5.mgh', '.inter_z.intra_z.combat.on_lh.thickness.sm10.mgh', '.inter_z.intra_z.combat.on_lh.w-g.pct.sm10.mgh', '.inter_z.intra_z.combat.on_lh.wm_FLAIR_0.5.sm10.mgh', '.inter_z.intra_z.combat.on_lh.wm_FLAIR_1.sm10.mgh']
# DEBUG:meld_classifier.meld_cohort:selecting subjects that have features: []
# DEBUG:meld_classifier.meld_cohort:selecting subjects that don't have features: []
# INFO:meld_classifier.meld_cohort:total number after filtering by scanner ['3T', '15T'], features, lesional_only True: 373
# INFO:meld_classifier.meld_cohort:total number of subjects: 577
# INFO:meld_classifier.meld_cohort:total number of subjects after restricting to subjects from MELD_dataset_V6.csv: 569
# DEBUG:meld_classifier.meld_cohort:selecting subjects that have features: []
# DEBUG:meld_classifier.meld_cohort:selecting subjects that don't have features: []
# INFO:meld_classifier.meld_cohort:total number after filtering by scanner ['3T', '15T'], features, lesional_only True: 538

# %%
controls
# Out:
# ['MELD_H12_3T_C_0001',
#  'MELD_H12_3T_C_0002',
#  'MELD_H12_3T_C_0003',
#  'MELD_H12_3T_C_0004',
#  'MELD_H4_3T_C_0017',
#  'MELD_H4_3T_C_0018',
#  'MELD_H4_3T_C_0019',
#  'MELD_H2_15T_C_0001',
#  'MELD_H2_15T_C_0002',
#  'MELD_H2_15T_C_0003',
#  'MELD_H2_15T_C_0004',
#  'MELD_H2_15T_C_0005',
#  'MELD_H2_3T_C_0001',
#  'MELD_H2_3T_C_0002',
#  'MELD_H2_3T_C_0003',
#  'MELD_H2_3T_C_0004',
#  'MELD_H2_3T_C_0006',
#  'MELD_H2_3T_C_0007',
#  'MELD_H2_3T_C_0008',
#  'MELD_H2_3T_C_0009',
#  'MELD_H2_3T_C_0010',
#  'MELD_H2_3T_C_0011',
#  'MELD_H2_3T_C_0012',
#  'MELD_H2_3T_C_0013',
#  'MELD_H2_3T_C_0014',
#  'MELD_H2_3T_C_0015',
#  'MELD_H2_3T_C_0017',
#  'MELD_H2_3T_C_0018',
#  'MELD_H2_3T_C_0019',
#  'MELD_H2_3T_C_0020',
#  'MELD_H2_3T_C_0021',
#  'MELD_H2_3T_C_0024',
#  'MELD_H2_3T_C_0025',
#  'MELD_H2_3T_C_0027',
#  'MELD_H2_3T_C_0028',
#  'MELD_H2_3T_C_0029',
#  'MELD_H2_3T_C_0030',
#  'MELD_H2_3T_C_0031',
#  'MELD_H9_3T_C_0002',
#  'MELD_H9_3T_C_0003',
#  'MELD_H9_3T_C_0004',
#  'MELD_H9_3T_C_0005',
#  'MELD_H9_3T_C_0007',
#  'MELD_H9_3T_C_0009',
#  'MELD_H15_3T_C_0001',
#  'MELD_H15_3T_C_0002',
#  'MELD_H15_3T_C_0003',
#  'MELD_H15_3T_C_0004',
#  'MELD_H15_3T_C_0005',
#  'MELD_H15_3T_C_0006',
#  'MELD_H15_3T_C_0007',
#  'MELD_H15_3T_C_0008',
#  'MELD_H15_3T_C_0009',
#  'MELD_H15_3T_C_0010',
#  'MELD_H15_3T_C_0011',
#  'MELD_H15_3T_C_0012',
#  'MELD_H15_3T_C_0013',
#  'MELD_H15_3T_C_0014',
#  'MELD_H15_3T_C_0015',
#  'MELD_H15_3T_C_0016',
#  'MELD_H15_3T_C_0017',
#  'MELD_H15_3T_C_0018',
#  'MELD_H15_3T_C_0019',
#  'MELD_H15_3T_C_0020',
#  'MELD_H15_3T_C_0021',
#  'MELD_H15_3T_C_0022',
#  'MELD_H15_3T_C_0023',
#  'MELD_H15_3T_C_0024',
#  'MELD_H15_3T_C_0025',
#  'MELD_H15_3T_C_0026',
#  'MELD_H15_3T_C_0027',
#  'MELD_H15_3T_C_0028',
#  'MELD_H15_3T_C_0029',
#  'MELD_H15_3T_C_0030',
#  'MELD_H15_3T_C_0031',
#  'MELD_H15_3T_C_0032',
#  'MELD_H15_3T_C_0033',
#  'MELD_H15_3T_C_0034',
#  'MELD_H15_3T_C_0035',
#  'MELD_H15_3T_C_0036',
#  'MELD_H15_3T_C_0037',
#  'MELD_H14_3T_C_0001',
#  'MELD_H14_3T_C_0002',
#  'MELD_H14_3T_C_0003',
#  'MELD_H14_3T_C_0004',
#  'MELD_H14_3T_C_0005',
#  'MELD_H14_3T_C_0006',
#  'MELD_H14_3T_C_0007',
#  'MELD_H3_3T_C_0069',
#  'MELD_H3_3T_C_0070',
#  'MELD_H3_3T_C_0071',
#  'MELD_H3_3T_C_0072',
#  'MELD_H3_3T_C_0073',
#  'MELD_H3_3T_C_0074',
#  'MELD_H3_3T_C_0075',
#  'MELD_H3_3T_C_0076',
#  'MELD_H3_3T_C_0077',
#  'MELD_H3_3T_C_0078',
#  'MELD_H3_3T_C_0079',
#  'MELD_H3_3T_C_0080',
#  'MELD_H3_3T_C_0081',
#  'MELD_H3_3T_C_0082',
#  'MELD_H3_3T_C_0083',
#  'MELD_H3_3T_C_0084',
#  'MELD_H3_3T_C_0085',
#  'MELD_H3_3T_C_0086',
#  'MELD_H3_3T_C_0087',
#  'MELD_H3_3T_C_0088',
#  'MELD_H3_3T_C_0089',
#  'MELD_H3_3T_C_0090',
#  'MELD_H3_3T_C_0091',
#  'MELD_H3_3T_C_0092',
#  'MELD_H3_3T_C_0093',
#  'MELD_H3_3T_C_0094',
#  'MELD_H3_3T_C_0095',
#  'MELD_H3_3T_C_0096',
#  'MELD_H3_3T_C_0097',
#  'MELD_H3_3T_C_0098',
#  'MELD_H3_3T_C_0099',
#  'MELD_H3_3T_C_0100',
#  'MELD_H10_3T_C_0002',
#  'MELD_H10_3T_C_0003',
#  'MELD_H10_3T_C_0004',
#  'MELD_H10_3T_C_0005',
#  'MELD_H10_3T_C_0006',
#  'MELD_H10_3T_C_0007',
#  'MELD_H10_3T_C_0008',
#  'MELD_H10_3T_C_0009',
#  'MELD_H10_3T_C_0010',
#  'MELD_H10_3T_C_0011',
#  'MELD_H10_3T_C_0012',
#  'MELD_H10_3T_C_0013',
#  'MELD_H10_3T_C_0014',
#  'MELD_H10_3T_C_0015',
#  'MELD_H10_3T_C_0016',
#  'MELD_H10_3T_C_0017',
#  'MELD_H10_3T_C_0018',
#  'MELD_H10_3T_C_0019',
#  'MELD_H10_3T_C_0020',
#  'MELD_H10_3T_C_0021',
#  'MELD_H10_3T_C_0022',
#  'MELD_H10_3T_C_0023',
#  'MELD_H10_3T_C_0024',
#  'MELD_H10_3T_C_0025',
#  'MELD_H10_3T_C_0026',
#  'MELD_H10_3T_C_0027',
#  'MELD_H10_3T_C_0028',
#  'MELD_H10_3T_C_0029',
#  'MELD_H10_3T_C_0030',
#  'MELD_H10_3T_C_0031',
#  'MELD_H10_3T_C_0032',
#  'MELD_H19_3T_C_007',
#  'MELD_H19_3T_C_008',
#  'MELD_H19_3T_C_009',
#  'MELD_H19_3T_C_010',
#  'MELD_H19_3T_C_011',
#  'MELD_H19_3T_C_012',
#  'MELD_H19_3T_C_013',
#  'MELD_H19_3T_C_014',
#  'MELD_H19_3T_C_015',
#  'MELD_H19_3T_C_016',
#  'MELD_H19_3T_C_017',
#  'MELD_H19_3T_C_018',
#  'MELD_H19_3T_C_019',
#  'MELD_H19_3T_C_020',
#  'MELD_H19_3T_C_021',
#  'MELD_H19_3T_C_022',
#  'MELD_H19_3T_C_023',
#  'MELD_H19_3T_C_024',
#  'MELD_H19_3T_C_025',
#  'MELD_H19_3T_C_026',
#  'MELD_H19_3T_C_027',
#  'MELD_H19_3T_C_028',
#  'MELD_H19_3T_C_029',
#  'MELD_H19_3T_C_030',
#  'MELD_H19_3T_C_031',
#  'MELD_H5_3T_C_0001',
#  'MELD_H5_3T_C_0002',
#  'MELD_H5_3T_C_0003',
#  'MELD_H5_3T_C_0004',
#  'MELD_H5_3T_C_0005',
#  'MELD_H5_3T_C_0006',
#  'MELD_H5_3T_C_0007',
#  'MELD_H5_3T_C_0008',
#  'MELD_H5_3T_C_0009',
#  'MELD_H5_3T_C_0010',
#  'MELD_H5_3T_C_0011',
#  'MELD_H5_3T_C_0012',
#  'MELD_H5_3T_C_0013',
#  'MELD_H5_3T_C_0014',
#  'MELD_H5_3T_C_0015',
#  'MELD_H5_3T_C_0016',
#  'MELD_H5_3T_C_0017',
#  'MELD_H5_3T_C_0018',
#  'MELD_H5_3T_C_0019',
#  'MELD_H5_3T_C_0020',
#  'MELD_H5_3T_C_0021',
#  'MELD_H5_3T_C_0022',
#  'MELD_H5_3T_C_0023',
#  'MELD_H5_3T_C_0024',
#  'MELD_H5_3T_C_0025',
#  'MELD_H5_3T_C_0026',
#  'MELD_H5_3T_C_0027',
#  'MELD_H5_3T_C_0028',
#  'MELD_H5_3T_C_0029']

# %%
# initialise dictionary to save all results
values={}

# %%
#loop over experiments
labels_to_pair=[]
for exp in [
        'radius0.5', 'radius2',
         'bias0.1', 
        'bias1', 
        'bias2',
         'real_patients', 
         'real_controls'
         ]:
    if exp=='radius0.5':
        data_parameters['synthetic_data']['run_synthetic'] = True
        data_parameters['synthetic_data']['radius'] = 0.5
        subjects=controls
    elif exp=='radius2':
        data_parameters['synthetic_data']['run_synthetic'] = True
        data_parameters['synthetic_data']['radius'] = 2
        subjects=controls
    elif exp=='bias0.1':
        data_parameters['synthetic_data']['run_synthetic'] = True
        data_parameters['synthetic_data']['radius'] = 2
        data_parameters['synthetic_data']['bias'] = 0.1
        subjects=controls
    elif exp=='bias1':
        data_parameters['synthetic_data']['run_synthetic'] = True
        data_parameters['synthetic_data']['radius'] = 2
        data_parameters['synthetic_data']['bias'] = 1
        subjects=controls
    elif exp=='bias2':
        data_parameters['synthetic_data']['run_synthetic'] = True
        data_parameters['synthetic_data']['radius'] = 2
        data_parameters['synthetic_data']['bias'] = 2
        subjects=controls
    elif exp=='real_patients':
        data_parameters['synthetic_data']['run_synthetic'] = False
        subjects=patients
    elif exp=='real_controls':
        data_parameters['synthetic_data']['run_synthetic'] = False
        subjects=controls
    else:
        print('exp does not exists')


    dataset = GraphDataset(subjects, cohort, data_parameters, mode='test' , distance_maps=True)

    flair_lesion = []
    thick_lesion = []
    wg_lesion = []
    # intrinsic_nonlesion = []
    # thick_nonlesion = []
    # wg_nonlesion = []
    lesion_size = []

    if exp != 'real_controls':
        for i, sub in enumerate(range(0, len(dataset.data_list))):
            #get lesion size
            labels = dataset.data_list[sub]['labels']
            if labels.sum() != 0:
                lesion_size.append(labels.sum())
                if exp== 'real_patients':
                    labels_to_pair.append(labels)

                # get feature values in lesion
                feats_lesion = dataset.data_list[sub]['features'][(labels==1)&cohort.cortex_mask,:]
                feats_nolesion = dataset.data_list[sub]['features'][(labels!=1)&cohort.cortex_mask,:]
                if feats_nolesion[:,0].any() != 0:
                    flair_lesion.append(abs(feats_lesion[:,0]).mean())
                thick_lesion.append(abs(feats_lesion[:,1]).mean())
                wg_lesion.append(abs(feats_lesion[:,2]).mean())

    else:
        for i, sub in enumerate(range(0, len(dataset.data_list),2)):
            #pair with patients to get mask
            index_pairing = random.randint(0, len(labels_to_pair)-1)
            labels = labels_to_pair[i]
            if labels.sum() != 0:
                # get feature values in lesion
                feats_lesion = dataset.data_list[sub]['features'][(labels==1)&cohort.cortex_mask,:]
                feats_nolesion = dataset.data_list[sub]['features'][(labels!=1)&cohort.cortex_mask,:]
                if feats_nolesion[:,0].any() != 0:
                    flair_lesion.append(abs(feats_lesion[:,0]).mean())
                thick_lesion.append(abs(feats_lesion[:,1]).mean())
                wg_lesion.append(abs(feats_lesion[:,2]).mean())
        
    values[exp]={}
    values[exp]['FLAIR'] = flair_lesion
    values[exp]['thickness'] = thick_lesion
    values[exp]['g-w contrast'] = wg_lesion
    # values[exp]['intrinsic curvature healthy'] = intrinsic_nonlesion
    # values[exp]['thickness healthy'] = thick_nonlesion
    # values[exp]['g-w contrast healthy'] = wg_nonlesion
    values[exp]['lesion size'] = lesion_size
# Out:
# DEBUG:meld_graph.icospheres:Using coord type pseudo
# INFO:meld_graph.dataset:Loading and preprocessing test data
# DEBUG:meld_graph.dataset:Combine hemis None
# INFO:meld_graph.dataset:WARNING: Simulating 500 subjects using 373 controls
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# dataset using distance_maps
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0001
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0002
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0003
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0004
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0005
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0006
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0007
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0010
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0011
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0013
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0014
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0016
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0017
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0018
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0021
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0023
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0024
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0025
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0026
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0027
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0028
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0029
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0030
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0031
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0032
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0033
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0034
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0035
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0036
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0037
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0038
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0039
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0040
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0041
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0042
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0043
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0044
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0045
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0046
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0047
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0048
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0049
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0050
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0051
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H12_3T_C_0052
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0001
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0002
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0003
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0004
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0005
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0006
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0007
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0008
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0009
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0011
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0012
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0013
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0014
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0015
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0016
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0017
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0018
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0019
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0020
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0022
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0023
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0024
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0025
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0026
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0027
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0028
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0029
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_15T_C_0030
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0001
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0002
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0003
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0004
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0005
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0007
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0008
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0009
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0010
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0011
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0012
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0013
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0014
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0015
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0016
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0017
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0018
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H4_3T_C_0019
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_15T_C_0001
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_15T_C_0002
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_15T_C_0003
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_15T_C_0004
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_15T_C_0005
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0001
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0002
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0003
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0004
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0006
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0007
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0008
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0009
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0010
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0011
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0012
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0013
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0014
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0015
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0017
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0018
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0019
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0020
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0021
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0024
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0025
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0027
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0028
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0029
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0030
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H2_3T_C_0031
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H9_3T_C_0002
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H9_3T_C_0003
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H9_3T_C_0004
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# ...
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H19_3T_C_027
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H19_3T_C_028
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H19_3T_C_029
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H19_3T_C_030
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H19_3T_C_031
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0001
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0002
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0003
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0004
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0005
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0006
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0007
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0008
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0009
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0010
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0011
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0012
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0013
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0014
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0015
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0016
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0017
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0018
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0019
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0020
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0021
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0022
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0023
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0024
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0025
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0026
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0027
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0028
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero
# INFO:meld_graph.data_preprocessing:Z-scoring data for MELD_H5_3T_C_0029
# DEBUG:meld_classifier.meld_cohort:missing feature: .inter_z.asym.intra_z.combat.on_lh.gm_FLAIR_0.75.sm10.mgh set to zero
# DEBUG:meld_classifier.meld_cohort:missing feature: .on_lh.lesion.mgh set to zero

# %%
values.keys()
# Out:
# dict_keys(['radius0.5', 'radius2', 'bias0.1', 'bias1', 'real'])

# %% [markdown]
# ## plot lesion size

# %%
import matplotlib.pyplot as plt
bins=np.histogram(np.hstack((values['real_patients']['lesion size'],
                            values['radius2']['lesion size'],
                            values['radius0.5']['lesion size'])), bins=40)[1]
plt.hist(values['real_patients']['lesion size'], bins=bins, label='real lesion', color='red', alpha=0.7, density=True)
plt.hist(values['radius2']['lesion size'], bins=bins, label='synthetic lesion radius 2', color='darkblue', alpha=0.7, density=True)
plt.hist(values['radius0.5']['lesion size'], bins=bins, label='synthetic lesion radius 0.5', color='cyan', alpha=0.7, density=True)
plt.xlabel("lesion size (number of vertices)")
plt.ylabel("density")
plt.xlim(xmin=1, xmax = 80000)
plt.legend()

# %% [markdown]
# ## plot features

# %%
# # plot barplot

# X = ['thickness','g-w contrast', 'intrinsic curvature']
# bias1 = [np.array(values['bias1'][f'{feature} lesion']).mean() for feature in X]
# bias01 = [np.array(values['bias0.1'][f'{feature} lesion']).mean() for feature in X]
# real_les = [np.array(values['real'][f'{feature} lesion']).mean() for feature in X]
# real_noles = [np.array(values['real'][f'{feature} healthy']).mean() for feature in X]

# X_axis = np.arange(len(X))

# plt.bar(X_axis -0.4, real_les, 0.2, label = 'real lesion', color='red')
# plt.bar(X_axis -0.2, real_noles, 0.2, label = 'real nolesion', color='green')
# plt.bar(X_axis + 0, bias1, 0.2, label = 'synthetic bias 1', color='darkblue')
# plt.bar(X_axis + 0.2, bias01, 0.2, label = 'synthetic bias 0.1', color='cyan')

# plt.xticks(X_axis, X)
# plt.xlabel("Feature")
# plt.ylabel("mean(abs(z))")
# plt.legend()
# plt.show()

# %%
# plot boxplot
X = ['thickness','g-w contrast', 'FLAIR']
bias1 = [np.array(values['bias1'][f'{feature}']) for feature in X]
bias01 = [np.array(values['bias0.1'][f'{feature}']) for feature in X]
bias2 = [np.array(values['bias2'][f'{feature}']) for feature in X]
real_les = [np.array(values['real_patients'][f'{feature}'])for feature in X]
real_noles = [np.array(values['real_controls'][f'{feature}']) for feature in X]

X_axis = np.arange(len(X))

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    
bp1=plt.boxplot(real_les, positions=np.array(range(len(real_les)))-0.2, sym='', widths=0.1)
bp2=plt.boxplot(real_noles, positions= np.array(range(len(real_noles)))-0.1, sym='', widths=0.1, )
bp3=plt.boxplot(bias01, positions =  np.array(range(len(bias01))),sym='', widths=0.1)
bp4=plt.boxplot(bias1, positions=  np.array(range(len(bias1))) +0.1 ,sym='', widths=0.1,)
bp5=plt.boxplot(bias2, positions=  np.array(range(len(bias1))) +0.2 ,sym='', widths=0.1,)


set_box_color(bp1, 'red') 
set_box_color(bp2, 'green')
set_box_color(bp3, 'cyan')
set_box_color(bp4, 'royalblue') 
set_box_color(bp5, 'darkblue') 


# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='red', label='real lesion')
plt.plot([], c='green', label='real control')
plt.plot([], c='cyan', label='synthetic bias 0.1')
plt.plot([], c='royalblue', label='synthetic bias 1')
plt.plot([], c='darkblue', label='synthetic bias 2')
plt.legend()
plt.xticks(X_axis, X)
plt.ylim(ymin=0, ymax = 6)
plt.xlabel("Feature")
plt.ylabel("mean(abs(z))")
plt.show()

# %%
values['bias1'][f'flair']
# Out:
# [0.013068002,
#  0.0075289104,
#  0.025640078,
#  0.02598876,
#  0.015865548,
#  0.009241283,
#  0.008566252,
#  0.011784203,
#  0.010157233,
#  0.015278369,
#  0.036972027,
#  0.010434398,
#  0.05135638,
#  0.01962012,
#  0.007805102,
#  0.032689072,
#  0.012339325,
#  0.012191052,
#  0.0033422797,
#  0.0061563817,
#  0.018555302,
#  0.0028763823,
#  0.017395005,
#  0.013675215,
#  0.0030520821,
#  0.004440915,
#  0.0108162025,
#  0.0077802106,
#  0.0003006131,
#  0.0056688343,
#  0.012859224,
#  0.039269645,
#  0.011261528,
#  0.009853626,
#  0.010707838,
#  0.014741418,
#  0.018600548,
#  0.024866106,
#  0.02536846,
#  0.05288666,
#  0.04936672,
#  0.019239139,
#  0.6605958,
#  0.7356513,
#  0.6645631,
#  0.7319723,
#  0.6864104,
#  0.7950344,
#  0.47120133,
#  0.49764413,
#  0.5527304,
#  0.56805944,
#  0.49405563,
#  1.1614985,
#  0.666592,
#  0.52389735,
#  0.71268165,
#  0.7252031,
#  1.0656161,
#  0.92585284,
#  1.0255672,
#  0.83380556,
#  0.7902005,
#  0.76377743,
#  0.74018335,
#  0.9980132,
#  1.1080447,
#  0.7004211,
#  0.7439409,
#  0.76671904,
#  0.8003879,
#  0.72851753,
#  0.84428227,
#  0.22927073,
#  0.48730335,
#  0.60575086,
#  0.63776827,
#  0.6209961,
#  0.74982905,
#  0.72215635,
#  0.6437435,
#  0.8372155,
#  0.88106567,
#  0.6078929,
#  0.5516198,
#  0.7625577,
#  0.9363599,
#  0.7808165,
#  0.5953965,
#  0.44512525,
#  0.51836354,
#  0.60152876,
#  0.52793777,
#  0.5211717,
#  0.5732019,
#  0.52974284,
#  0.7702357,
#  0.7039932,
#  0.49642676,
#  0.5384871,
#  0.6910069,
#  0.61435235,
#  0.6956511,
#  0.7792003,
#  1.0188862,
#  0.7681221,
#  0.70570755,
#  0.6330808,
#  0.67797613,
#  0.822675,
#  0.6292287,
#  0.6409671,
#  0.6388772,
#  0.5847474,
#  0.6298646,
#  0.668269,
#  0.6769835,
#  0.0016005933,
#  0.034053896,
#  0.017015534,
#  0.014421927,
#  0.005818195,
#  0.005202706,
#  0.032787986,
#  0.022409966,
#  0.009783835,
#  0.008859775,
#  0.020910343,
#  0.006156169,
#  0.014552041,
#  0.01095604,
#  0.00852071,
#  0.007575816,
#  0.036315285,
#  0.020460408,
#  0.00397613,
#  0.05604642,
#  0.008848668,
#  0.033929404,
#  0.02024955,
#  0.03201813,
#  0.0034373405,
#  0.0081923455,
#  0.0220727,
#  0.009294959,
#  0.0053209956,
#  0.010611822,
#  0.005279193,
#  0.043874595,
#  0.010659748,
#  0.017621007,
#  0.02676305,
#  0.00097214704,
#  0.023543628,
#  0.010604307,
#  0.007833727,
#  0.026964832,
#  0.03788374,
#  0.014503161,
#  0.026132341,
#  0.64487725,
#  0.6180121,
#  0.5684303,
#  0.016539572,
#  0.013238942,
#  0.017171664,
#  0.018012015,
#  0.02644098,
#  0.013806384,
#  0.016362635,
#  0.008286239,
#  0.02666866,
#  0.023432337,
#  0.015887287,
#  0.02021918,
#  0.029670978,
#  0.030607944,
#  0.019899558,
#  0.0036822113,
#  0.031176245,
#  0.0026209021,
#  0.021618575,
#  0.017591894,
#  0.016278341,
#  0.014551805,
#  0.0029964284,
#  0.0036515996,
#  0.0050083213,
#  0.013617439,
#  0.023586256,
#  0.035116788,
#  0.031777978,
#  0.02739277,
#  0.0062699313,
#  0.03158521,
#  0.025732847,
#  0.02971134,
#  0.0067325537,
#  0.018173551,
#  0.0090193,
#  0.030739851,
#  0.015020592,
#  0.0223481,
#  0.015816567,
#  0.013818696,
#  0.0111033125,
#  0.012936424,
#  0.003484775,
#  0.0064802337,
#  0.009251897,
#  0.020441981,
#  0.015004604,
#  0.02106723,
#  0.028041866,
#  0.0051104254,
#  0.012843487,
#  0.008926683,
#  0.03696131,
#  0.009465993,
#  0.004785436,
#  0.00962235,
#  0.0060498356,
#  0.012352631,
#  0.021681031,
#  0.01671472,
#  0.019731965,
#  0.020309674,
#  0.008331487,
#  0.014288199,
#  0.019000862,
#  0.025204016,
#  0.016044555,
#  0.037502524,
#  0.01555739,
#  0.012419446,
#  0.024971334,
#  0.012644024,
#  0.01685259,
#  0.012114521,
#  0.0035432281,
#  0.012341649,
#  0.022567453,
#  0.022329627,
#  0.023020217,
#  0.02286864,
#  0.022192905,
#  0.0034959423,
#  0.019798342,
#  0.035628144,
#  0.00975223,
#  0.025342042,
#  0.026623724,
#  0.00892336,
#  0.021348894,
#  0.031474736,
#  0.0054018754,
#  0.0313445,
#  0.010661568,
#  0.0059610996,
#  0.003593333,
#  0.0060936143,
#  0.0034372169,
#  0.008793496,
#  0.0005408727,
#  0.03886213,
#  0.00882539,
#  0.03141654,
#  0.0053679445,
#  0.027394025,
#  0.030565865,
#  0.016750272,
#  0.0045891926,
#  0.00995304,
#  0.015331809,
#  0.014473512,
#  0.01860791,
#  0.054288868,
#  0.01895968,
#  0.01624285,
#  0.0108226035,
#  0.026139593,
#  0.034369793,
#  0.0066301106,
#  0.014715792,
#  0.010952071,
#  0.027673302,
#  0.022786671,
#  0.00337271,
#  0.021693556,
#  0.0068352227,
#  0.00056980684,
#  0.0062197912,
#  0.02799904,
#  0.0137472,
#  0.011175583,
#  0.0007400597,
#  0.02981934,
#  0.031487226,
#  0.005692757,
#  0.03756622,
#  0.014721606,
#  0.011590288,
#  0.014326128,
#  0.010526867,
#  0.02357793,
#  0.027267523,
#  0.019549185,
#  0.015802862,
#  0.0208717,
#  0.028268954,
#  0.013712943,
#  0.01104655,
#  0.008492172,
#  0.005052626,
#  0.009664631,
#  0.015522063,
#  0.0052546584,
#  0.012350424,
#  0.021161819,
#  0.04075366,
#  0.006306475,
#  0.022877038,
#  0.01683444,
#  0.013866795,
#  0.014166687,
#  0.010917163,
#  0.0044327714,
#  0.009211987,
#  0.006668151,
#  0.008853211,
#  0.018903961,
#  0.013333679,
#  0.00967334]

# %%
np.array(values['bias1']['thickness']).mean()
# Out:
# nan
